# %% [markdown]
# # Conversation Tree with Audio Generation
#
# This notebook processes educational conversations from CSV files and generates interactive conversation trees with AI-generated audio using the Kokoro text-to-speech model.
#
# ## Overview
#
# The notebook performs the following steps:
# 1. **Data Processing**: Reads conversation CSV files and creates a structured conversation tree
# 2. **Audio Generation**: Uses Kokoro TTS to generate audio files for each dialogue turn
# 3. **Link Integration**: Adds audio download links to the conversation tree structure
#
# ## Prerequisites & Installation
#
# ### Required Dependencies
# - Python packages: `kokoro`, `soundfile`, `numpy`, `spacy`
# - spaCy English model: `en_core_web_sm`
#
# ### espeak-ng Installation (Brief Guide)
#
# **Windows:**
# ```bash
# # Using Chocolatey (recommended)
# choco install espeak
#
# # Or download installer from: https://github.com/espeak-ng/espeak-ng/releases
# ```
#
# **Linux (Ubuntu/Debian):**
# ```bash
# sudo apt-get update
# sudo apt-get install espeak-ng
# ```
#
# **macOS:**
# ```bash
# # Using Homebrew
# brew install espeak-ng
# ```
#
# **Verify Installation:**
# ```bash
# espeak-ng --version
# ```
#
# > **Note**: espeak-ng provides phonetic processing capabilities that may be used by some TTS engines, though Kokoro primarily uses its own neural processing pipeline.
#
# ## Input Data Structure
#
# The notebook expects:
# - `simplified/questions-3-items.json`: Root questions file
# - `simplified/mini-conversations/`: Folder containing conversation CSV files
# - CSV format with columns: `who`, `content`, `original_question`

# %%
import os
import csv
import json
import re
from collections import defaultdict

# Clean up text from tags and excess whitespace
def strip_tags(text):
    text = re.sub(r"</?[^>]+>", "", text)
    return re.sub(r"\s+", " ", text).strip()

# Load root questions
with open("simplified/questions-3-items.json", "r", encoding="utf-8") as f:
    data = json.load(f)

root_questions = []
for assessment in data["assessments"]:
    for question in assessment["questions"]:
        root_questions.append(strip_tags(question["text"]))

# Process CSVs into organized threads
conversation_folder = "simplified/mini-conversations"
conversations_by_question = defaultdict(lambda: defaultdict(list))  # {question: {teacher_id: [dialogue]}}

for filename in sorted(os.listdir(conversation_folder)):  # Alphabetical sorting
    if not filename.endswith(".csv"):
        continue

    parts = filename.replace(".csv", "").split("_")
    teacher_num = parts[2]
    student_num = parts[4]
    teacher_id = f"teacher_{teacher_num}"
    student_id = f"student_{student_num}"

    filepath = os.path.join(conversation_folder, filename)
    with open(filepath, "r", encoding="utf-8") as f:
        lines = f.readlines()[4:]  # skip metadata
        reader = csv.DictReader(lines)

        current_question = None
        dialogue = []

        for row in reader:
            who = row["who"].strip().lower()
            content = strip_tags(row["content"].strip())
            orig_question = strip_tags(row.get("original_question", "").strip())

            if orig_question:
                if current_question and dialogue:
                    conversations_by_question[current_question][teacher_id].append({
                        "student_id": student_id,
                        "dialogue": dialogue
                    })
                current_question = orig_question
                dialogue = []

            if current_question:
                dialogue.append({
                    "speaker": f"{who}_{student_num if who == 'student' else teacher_num}",
                    "role": who,
                    "message": content
                })

        # Save last conversation
        if current_question and dialogue:
            conversations_by_question[current_question][teacher_id].append({
                "student_id": student_id,
                "dialogue": dialogue
            })

# Build tree
tree = {"questions": []}
tag_counters = defaultdict(int)

for q_idx, root_q in enumerate(root_questions, 1):
    teacher_dict = conversations_by_question.get(root_q)
    if not teacher_dict:
        continue

    question_node = {
        "speaker": "question",
        "message": root_q,
        "children": []
    }

    for teacher_id in sorted(teacher_dict.keys()):
        student_conversations = teacher_dict[teacher_id]
        for convo in sorted(student_conversations, key=lambda c: c["student_id"]):
            student_id = convo["student_id"]
            dialogue = convo["dialogue"]

            first_msg = next((m for m in dialogue if m["role"] == "teacher"), None)
            if not first_msg:
                continue

            tag_base = f"{teacher_id}_{student_id}_question_{q_idx}"
            tag_counters[tag_base] += 1

            teacher_node = {
                "speaker": first_msg["speaker"],
                "message": first_msg["message"],
                "tag": f"{tag_base}_{tag_counters[tag_base]:04d}",
                "responses": []
            }

            i = dialogue.index(first_msg) + 1
            last_message = first_msg["message"]
            current_node = teacher_node

            while i < len(dialogue):
                msg = dialogue[i]
                speaker = msg["speaker"]
                role = msg["role"]
                message = msg["message"]

                if message == last_message:
                    i += 1
                    continue

                # Merge same-speaker consecutive messages
                while i + 1 < len(dialogue) and dialogue[i + 1]["speaker"] == speaker:
                    next_msg = dialogue[i + 1]["message"]
                    if next_msg != message:
                        message += " " + next_msg
                        i += 1
                    else:
                        i += 1

                tag_counters[tag_base] += 1
                new_node = {
                    "speaker": speaker,
                    "message": message,
                    "tag": f"{tag_base}_{tag_counters[tag_base]:04d}"
                }

                current_node.setdefault("responses", []).append(new_node)
                current_node = new_node
                last_message = message
                i += 1

            question_node["children"].append(teacher_node)

    tree["questions"].append(question_node)

# Save the final tree
output_path = "conversation-tree.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(tree, f, indent=2)

print(f"Conversation tree saved to {output_path}")
# Out:
# Conversation tree saved to conversation-tree.json

# %% [markdown]
# ## Step 2: Audio Generation with Kokoro TTS
#
# This section generates individual audio files for each dialogue turn using the Kokoro text-to-speech model.
#
# ### What this code does:
# 1. **Initializes Kokoro TTS**: Sets up the neural text-to-speech pipeline
# 2. **Configures voice mapping**: Assigns different voices to teachers and students
#    - Teachers: `af_heart` (female voice)
#    - Students: `am_puck` (male pre-teen voice)
# 3. **Processes the conversation tree**: Recursively traverses all dialogue nodes
# 4. **Generates audio files**: Creates `.wav` files for each tagged dialogue turn
# 5. **Handles errors gracefully**: Continues processing even if individual files fail
#
# ### Voice Configuration:
# - **Teacher voice**: `af_heart` - Professional female voice for educators
# - **Student voice**: `am_puck` - Younger male voice for student responses
#
# ### Output:
# - Audio files saved to `audio/` directory
# - Files named using the unique tags from the conversation tree (e.g., `teacher_1_student_2_question_1_0001.wav`)

# %%
import os
import json
from kokoro import KPipeline
import soundfile as sf
import numpy as np
import traceback

try:
    # Check if spaCy model is available before initializing Kokoro
    import spacy
    try:
        nlp = spacy.load("en_core_web_sm")
        print("✓ spaCy model verified, initializing Kokoro...")
    except OSError:
        raise Exception("spaCy model 'en_core_web_sm' not found. Please run the previous cell to install it.")
    
    # Initialize Kokoro with explicit repo_id
    pipeline = KPipeline(lang_code='a', repo_id='hexgrad/Kokoro-82M')
    print("✓ Kokoro pipeline initialized successfully!")

    # Speaker-voice mapping
    voices = {
        "teacher": "af_heart",   # Female teacher
        "student": "am_puck"     # Male pre-teen
    }

    # Paths
    json_path = "conversation-tree-with-audio.json"
    output_dir = "audio"
    os.makedirs(output_dir, exist_ok=True)

    # Load JSON
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    # Recursive function to synthesize audio
    def synthesize_from_json(node):
        if isinstance(node, dict):
            if "tag" in node and "message" in node and "speaker" in node:
                tag = node["tag"]
                message = node["message"]
                speaker_type = node["speaker"].split("_")[0]
                voice = voices.get(speaker_type)

                if voice:
                    output_file = os.path.join(output_dir, f"{tag}.wav")
                    if not os.path.exists(output_file):
                        print(f"[Creating] {output_file} with voice '{voice}' and message:\n→ {message}\n")
                        try:
                            audio_segments = []
                            for chunk in pipeline(message, voice=voice):
                                audio_segments.append(chunk.audio.squeeze().cpu().numpy())
                            if audio_segments:
                                full_audio = np.concatenate(audio_segments)
                                sf.write(output_file, full_audio, 24000)
                        except Exception as e:
                            print(f"Error processing {tag}: {str(e)}")
                            traceback.print_exc()  # Show the full traceback for individual file errors
                            return  # Return instead of continue since we're not in a loop
                    else:
                        print(f"[Skipping] {output_file} already exists.\n")

            # Recurse into children and responses
            for key in node:
                if isinstance(node[key], (dict, list)):
                    synthesize_from_json(node[key])

        elif isinstance(node, list):
            for item in node:
                synthesize_from_json(item)

    # Run
    print("Starting audio generation...\n")
    synthesize_from_json(data)
    print("Audio generation completed.")

except Exception as e:
    print("An exception has occurred:")
    print(f"Exception type: {type(e).__name__}")
    print(f"Exception message: {str(e)}")
    traceback.print_exc()
# Out:
# ✓ spaCy model verified, initializing Kokoro...
# ✓ Kokoro pipeline initialized successfully!
# Starting audio generation...
#
# [Creating] audio\teacher_1_question_1_0001.wav with voice 'af_heart' and message:
# → Good morning! Let's explore this together. In the context of projectile motion, how would you define a projectile?
#
# [Creating] audio\student_2_question_1_0001.wav with voice 'am_puck' and message:
# → Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.
#
# [Creating] audio\teacher_1_question_1_0002.wav with voice 'af_heart' and message:
# → You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.
#
# [Creating] audio\student_2_question_1_0002.wav with voice 'am_puck' and message:
# → Okay, so it's mainly about gravity then, for the ideal one.
#
# [Creating] audio\teacher_1_question_1_0003.wav with voice 'af_heart' and message:
# → You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?
#
# [Creating] audio\student_2_question_1_0003.wav with voice 'am_puck' and message:
# → Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.
#
# [Creating] audio\teacher_1_question_1_0004.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_3_question_1_0001.wav with voice 'am_puck' and message:
# → A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.
#
# [Creating] audio\teacher_1_question_1_0005.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0001.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0006.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.
#
# [Creating] audio\student_2_question_1_0004.wav with voice 'am_puck' and message:
# → Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.
#
# [Creating] audio\teacher_1_question_1_0007.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_3_question_1_0002.wav with voice 'am_puck' and message:
# → A projectile is any object that's thrown or launched into the air. Once it's moving, the primary force that pulls it back down is gravity.
#
# [Creating] audio\teacher_1_question_1_0008.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0002.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0009.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile?
#
# Think of an object that is launched or thrown, and remember that its path through the air is mainly determined by a specific natural force. Now, how would you describe a projectile?
#
# [Creating] audio\student_3_question_1_0003.wav with voice 'am_puck' and message:
# → Yes, I see, Teacher. So, for the ideal definition, the focus is just on gravity, and other forces like air resistance aren't considered. That makes a lot of sense for simplifying the concept. I'm ready.
#
# [Creating] audio\teacher_1_question_1_0010.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile?
#
# [Creating] audio\student_2_question_1_0005.wav with voice 'am_puck' and message:
# → A projectile is like anything that gets launched or thrown into the air.
#
# [Creating] audio\teacher_1_question_1_0011.wav with voice 'af_heart' and message:
# → You've mentioned that a projectile is an object launched or thrown into the air, which is a good start. However, your definition is not yet complete. Think of the primary force that acts on the object once it is in the air.
#
# [Creating] audio\student_2_question_1_0006.wav with voice 'am_puck' and message:
# → Oh, okay! So it's about the force that pulls it down, right? Like gravity?
#
# [Creating] audio\teacher_1_question_1_0012.wav with voice 'af_heart' and message:
# → You are correct that gravity is a crucial part of it. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0004.wav with voice 'am_puck' and message:
# → Oh, I see! So, a projectile is an object launched or thrown into the air, and once it's in the air, the only significant force acting on it is gravity.
#
# [Creating] audio\teacher_1_question_1_0013.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0003.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0014.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile? You mentioned you don't know.
#
# Think of an object that is launched into the air, and consider the primary force that acts upon it once it's in flight.
#
# [Creating] audio\student_3_question_1_0005.wav with voice 'am_puck' and message:
# → A projectile is an object that's launched or thrown into the air, and then the only force acting on it is gravity. We typically ignore air resistance in this context. It's really interesting how it follows that curved path!
#
# [Creating] audio\teacher_1_question_1_0015.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0004.wav with voice 'am_puck' and message:
# → Uh, I don't know.
#
# [Creating] audio\teacher_1_question_1_0016.wav with voice 'af_heart' and message:
# → Remember that a projectile is an object that is set in motion and then moves only under a specific natural force. Now, how would you describe a projectile?
#
# [Creating] audio\student_2_question_1_0007.wav with voice 'am_puck' and message:
# → Oh, so it's like when you throw something, or like a ball you kick, and then gravity just takes it over?
#
# [Creating] audio\teacher_1_question_1_0017.wav with voice 'af_heart' and message:
# → Good Job! That's it for that item.
#
# [Creating] audio\student_3_question_1_0006.wav with voice 'am_puck' and message:
# → Okay, so a projectile is an object that's set in motion and then, once it's moving, the only natural force acting on it is gravity.
#
# [Creating] audio\teacher_1_question_1_0018.wav with voice 'af_heart' and message:
# → That's a good attempt, but let's refine it to be more precise. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_6_question_1_0005.wav with voice 'am_puck' and message:
# → I dunno
#
# [Creating] audio\teacher_1_question_1_0019.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_6_question_1_0006.wav with voice 'am_puck' and message:
# → Uh... I don't know.
#
# [Creating] audio\teacher_1_question_1_0020.wav with voice 'af_heart' and message:
# → Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air.
#
# [Creating] audio\student_2_question_1_0008.wav with voice 'am_puck' and message:
# → It's gravity, right? That's the main one pulling things down.
#
# [Creating] audio\teacher_1_question_1_0021.wav with voice 'af_heart' and message:
# → Your answer correctly identifies gravity as a key factor. However, the definition of a projectile also involves how the object is initially set into motion. Think of how a projectile begins its movement. How is it typically put into the air?
#
# [Creating] audio\student_2_question_1_0009.wav with voice 'am_puck' and message:
# → Oh right. It's usually thrown or launched into the air.
#
# [Creating] audio\teacher_1_question_1_0022.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0007.wav with voice 'am_puck' and message:
# → Oh, I see! So, a projectile is also something that's given an initial push or throw, or launched into the air. Like, it's not just sitting there, it starts with a force.
#
# [Creating] audio\teacher_1_question_1_0023.wav with voice 'af_heart' and message:
# → That's a good start, but to be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_6_question_1_0007.wav with voice 'am_puck' and message:
# → I'm not sure.
#
# [Creating] audio\teacher_1_question_1_0024.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0008.wav with voice 'am_puck' and message:
# → Okay, I understand. Once a projectile is in the air, the primary force acting on it is gravity. It's always pulling it downwards, which makes sense because everything eventually falls.
#
# [Creating] audio\teacher_1_question_1_0025.wav with voice 'af_heart' and message:
# → You've correctly identified that gravity is a primary force acting on a projectile once it's in the air. However, to fully describe a projectile, consider what kind of object it is and how it initially gets into motion.
#
# Try to imagine what kind of object we are discussing and how it begins its movement into the air.
#
# [Creating] audio\student_2_question_1_0010.wav with voice 'am_puck' and message:
# → Oh, so it's like, anything that gets thrown or launched? Like a baseball? And it starts moving because something pushes it really hard, like when you throw it.
#
# [Creating] audio\teacher_1_question_1_0026.wav with voice 'af_heart' and message:
# → You are close! You correctly identified that it's anything that gets thrown or launched. However, a projectile is more precisely defined as any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0009.wav with voice 'am_puck' and message:
# → A projectile is an object that's launched or thrown into the air, and it gets its initial motion from that push or force that sends it off.
#
# [Creating] audio\teacher_1_question_1_0027.wav with voice 'af_heart' and message:
# → You're very close! You correctly identified that a projectile is an object launched or thrown. However, a key part of the definition is what continues to influence its motion once it's in the air.
#
# A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.
#
# [Creating] audio\student_6_question_1_0008.wav with voice 'am_puck' and message:
# → I... I don't really know.
#
# [Creating] audio\teacher_1_question_1_0028.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_6_question_1_0009.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0029.wav with voice 'af_heart' and message:
# → Try to imagine an object that has been launched into the air, and consider the primary force that acts upon it during its flight.
#
# [Creating] audio\student_2_question_1_0011.wav with voice 'am_puck' and message:
# → Hmm okay, an object launched into the air. So it goes up, and then it comes back down, right? I guess the main force acting on it would be gravity.
#
# [Creating] audio\teacher_1_question_1_0030.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_3_question_1_0010.wav with voice 'am_puck' and message:
# → Oh, that's an interesting thought experiment! The primary force acting on it would definitely be gravity.
#
# [Creating] audio\teacher_1_question_1_0031.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_6_question_1_0010.wav with voice 'am_puck' and message:
# → Uhm, I don't know.
#
# [Creating] audio\teacher_1_question_1_0032.wav with voice 'af_heart' and message:
# → Remember that a projectile is an object initially set into motion and then moves predominantly under a single natural force.
#
# [Creating] audio\student_3_question_1_0011.wav with voice 'am_puck' and message:
# → Good morning, teacher! I've really been focusing on this topic. From my understanding, a projectile is any object that's launched or thrown into the air, and then, once it's moving, the only important force acting on it is gravity.
#
# [Creating] audio\teacher_1_question_1_0033.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0011.wav with voice 'am_puck' and message:
# → Um, I don't know.
#
# [Creating] audio\teacher_1_question_1_0034.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile?
#
# Think of how you would make something fly through the air.
#
# [Creating] audio\student_2_question_1_0012.wav with voice 'am_puck' and message:
# → Oh, a projectile? It's basically anything that gets thrown or launched into the air, and then it just keeps going.
#
# [Creating] audio\teacher_1_question_1_0035.wav with voice 'af_heart' and message:
# → Your description is close, but it is incomplete. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_2_question_1_0013.wav with voice 'am_puck' and message:
# → Okay, I get it. So, gravity is the main thing that keeps it going.
#
# [Creating] audio\teacher_1_question_1_0036.wav with voice 'af_heart' and message:
# → You've correctly identified that gravity is a key factor. However, the definition of a projectile also describes how it begins its motion.
#
# Remember that a projectile needs an initial push or throw to start its journey. Please try to describe a projectile again, keeping both its initial motion and the influence of gravity in mind.
#
# [Creating] audio\student_2_question_1_0014.wav with voice 'am_puck' and message:
# → Okay, so a projectile is like something you throw or kick, and then gravity pulls it down as it flies through the air.
#
# [Creating] audio\teacher_1_question_1_0037.wav with voice 'af_heart' and message:
# → Good job. That's a very good description of a projectile.
#
# [Creating] audio\student_3_question_1_0012.wav with voice 'am_puck' and message:
# → Okay, so a projectile is an object that gets an initial push or throw, and then the only thing affecting its movement is gravity.
#
# [Creating] audio\teacher_1_question_1_0038.wav with voice 'af_heart' and message:
# → Good job. That's all for that question.
#
# [Creating] audio\student_6_question_1_0012.wav with voice 'am_puck' and message:
# → Uh, it's something that gets like, an initial push or throw, and then only gravity affects it.
#
# [Creating] audio\teacher_1_question_1_0039.wav with voice 'af_heart' and message:
# → Correct. That's all for that question.
#
# [Creating] audio\student_3_question_1_0013.wav with voice 'am_puck' and message:
# → Okay, so it's any object set in motion through the air, and then only gravity acts on it. Got it! That makes it clearer.
#
# [Creating] audio\teacher_1_question_1_0040.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0013.wav with voice 'am_puck' and message:
# → Right.
#
# [Creating] audio\teacher_1_question_1_0041.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_2_question_1_0015.wav with voice 'am_puck' and message:
# → Okay, makes sense.
#
# [Creating] audio\teacher_1_question_1_0042.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_3_question_1_0014.wav with voice 'am_puck' and message:
# → Okay, I understand. So it's just about gravity once it's in the air. Got it.
#
# [Creating] audio\teacher_1_question_1_0043.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.
#
# [Creating] audio\student_6_question_1_0014.wav with voice 'am_puck' and message:
# → Uh-huh.
#
# [Creating] audio\teacher_1_question_1_0044.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0015.wav with voice 'am_puck' and message:
# → Okay, so a projectile... thinking about how something flies through the air, it's basically any object that's been thrown, shot, or launched into space. And then, once it's moving, the only main force affecting its path is gravity, you know, pulling it downwards. That's how I'd describe it.
#
# [Creating] audio\teacher_1_question_1_0045.wav with voice 'af_heart' and message:
# → Your description is mostly accurate, highlighting the object being set in motion and gravity as the sole influence. However, consider the specific medium in which typical projectile motion occurs.
#
# Think of the environment where a projectile moves when we study it in physics.
#
# [Creating] audio\student_2_question_1_0016.wav with voice 'am_puck' and message:
# → Hmm, so like, the air around it?
#
# [Creating] audio\teacher_1_question_1_0046.wav with voice 'af_heart' and message:
# → Remember that a projectile is an object that is set into motion. Think of the specific force that acts upon this object once it is moving through the air, completely independent of its initial push.
#
# [Creating] audio\student_2_question_1_0017.wav with voice 'am_puck' and message:
# → Hmm, so after it's been pushed, the force that's always there... is it gravity?
#
# [Creating] audio\teacher_1_question_1_0047.wav with voice 'af_heart' and message:
# → You are correct that gravity is the force involved. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0016.wav with voice 'am_puck' and message:
# → That would be the force of gravity. It's the continuous downward pull on the object, completely independent of its initial push.
#
# [Creating] audio\teacher_1_question_1_0048.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_6_question_1_0015.wav with voice 'am_puck' and message:
# → I dunno.
#
# [Creating] audio\teacher_1_question_1_0049.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\student_3_question_1_0017.wav with voice 'am_puck' and message:
# → Oh, I see what you mean! When we talk about typical projectile motion, the object is usually moving through the air. So, air resistance would also be a factor, even if we sometimes simplify problems by neglecting it.
#
# [Creating] audio\teacher_1_question_1_0050.wav with voice 'af_heart' and message:
# → Your understanding of air resistance as a factor in real-world scenarios is correct. However, for the definition of an ideal projectile in physics, we often simplify the forces involved.
#
# Think about the action that starts an object on a projectile path and the fundamental natural force that continuously acts upon it as it travels through the air.
#
# [Creating] audio\student_2_question_1_0018.wav with voice 'am_puck' and message:
# → Okay, so for an ideal projectile, it starts with like, an initial push or launch, right? And then it's just gravity pulling it down the whole time?
#
# [Creating] audio\teacher_1_question_1_0051.wav with voice 'af_heart' and message:
# → Correct. That is a good description of a projectile.
#
# [Creating] audio\student_3_question_1_0018.wav with voice 'am_puck' and message:
# → Oh, I see! So for an ideal projectile, we're simplifying things. The action that starts it is its initial velocity, and the only continuous force acting on it would be gravity.
#
# [Creating] audio\teacher_1_question_1_0052.wav with voice 'af_heart' and message:
# → That's correct! Good job.
#
# [Creating] audio\student_6_question_1_0016.wav with voice 'am_puck' and message:
# → Um... just gravity, I guess?
#
# [Creating] audio\teacher_1_question_1_0053.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.
#
# [Creating] audio\student_6_question_1_0017.wav with voice 'am_puck' and message:
# → Um... it's usually in the air, right? But sometimes we just ignore the air part for the problems.
#
# [Creating] audio\teacher_1_question_1_0054.wav with voice 'af_heart' and message:
# → You are close, but let's refine that definition. Think of how the object begins its journey and what primary force acts upon it once it's moving through the air.
#
# [Creating] audio\student_2_question_1_0019.wav with voice 'am_puck' and message:
# → Oh, so it starts off with like, an initial push, right? And then gravity is the main thing pulling it down while it's in the air?
#
# [Creating] audio\teacher_1_question_1_0055.wav with voice 'af_heart' and message:
# → That's correct! You've accurately described a projectile.
#
# [Creating] audio\student_3_question_1_0019.wav with voice 'am_puck' and message:
# → Okay, I think I see what you mean. So, it starts when something is launched or thrown, and then the main force acting on it while it's in the air is gravity, pulling it downwards.
#
# [Creating] audio\teacher_1_question_1_0056.wav with voice 'af_heart' and message:
# → That's correct! A projectile is indeed an object that is launched or thrown, and its motion through the air is primarily influenced by gravity.
#
# [Creating] audio\student_6_question_1_0018.wav with voice 'am_puck' and message:
# → Uh... I guess it's when something gets, like, thrown, and then gravity just pulls it down while it's in the air?
#
# [Creating] audio\teacher_1_question_1_0057.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0019.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0058.wav with voice 'af_heart' and message:
# → Think of an object that is set in motion through the air, and what the only significant force acting upon it is once it's moving freely. What would you call such an object?
#
# [Creating] audio\student_2_question_1_0020.wav with voice 'am_puck' and message:
# → Hmm, like a baseball thrown in the air? I guess gravity would be the main force pulling it down. And... what do you call it? Is it a projectile?
#
# [Creating] audio\teacher_1_question_1_0059.wav with voice 'af_heart' and message:
# → That's correct! A projectile is indeed any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.
#
# [Creating] audio\student_3_question_1_0020.wav with voice 'am_puck' and message:
# → Oh, I've got this! So, if an object is set in motion through the air, like a basketball shot, the only significant force acting on it once it's freely moving is gravity. We would call that object a projectile.
#
# [Creating] audio\teacher_1_question_1_0060.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_1_0020.wav with voice 'am_puck' and message:
# → Uh, I don't know.
#
# [Creating] audio\teacher_1_question_1_0061.wav with voice 'af_heart' and message:
# → Within the topic of projectile motion, how would you describe a projectile?
#
# [Creating] audio\student_2_question_1_0021.wav with voice 'am_puck' and message:
# → Hmm, a projectile? I guess it's basically anything that gets thrown or launched into the air.
#
# [Creating] audio\teacher_1_question_1_0062.wav with voice 'af_heart' and message:
# → You are correct that a projectile is anything that gets thrown or launched into the air. To be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.
#
# [Creating] audio\student_3_question_1_0021.wav with voice 'am_puck' and message:
# → A projectile is essentially any object that's launched or thrown, and then its only significant force acting on it is gravity. We usually simplify it by not considering air resistance in our initial studies.
#
# [Creating] audio\teacher_1_question_1_0063.wav with voice 'af_heart' and message:
# → That's correct! You have accurately described a projectile.
#
# [Creating] audio\student_6_question_1_0021.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_1_0064.wav with voice 'af_heart' and message:
# → A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.
#
# [Creating] audio\teacher_1_question_2_0001.wav with voice 'af_heart' and message:
# → Hi there! I'd like you to think about something. What mathematical function describes the path of a projectile?
#
# [Creating] audio\student_2_question_2_0001.wav with voice 'am_puck' and message:
# → Oh, is it a quadratic function?
#
# [Creating] audio\teacher_1_question_2_0002.wav with voice 'af_heart' and message:
# → You are very close! A quadratic function does describe the path. Now, think of the specific geometric shape that the graph of a quadratic function creates. What is that shape called?
#
# [Creating] audio\student_2_question_2_0002.wav with voice 'am_puck' and message:
# → Oh, I remember that! It's called a parabola, right?
#
# [Creating] audio\teacher_1_question_2_0003.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_2_question_2_0003.wav with voice 'am_puck' and message:
# → Okay, cool!
#
# [Creating] audio\teacher_1_question_2_0004.wav with voice 'af_heart' and message:
# → What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_2_question_2_0004.wav with voice 'am_puck' and message:
# → Oh, it's that curve shape, like a parabola. So, it's a quadratic function, right?
#
# [Creating] audio\teacher_1_question_2_0005.wav with voice 'af_heart' and message:
# → That's correct! The path of a projectile follows a parabola, which is represented by a quadratic function.
#
# [Creating] audio\student_3_question_2_0001.wav with voice 'am_puck' and message:
# → It follows a quadratic function!
#
# [Creating] audio\teacher_1_question_2_0006.wav with voice 'af_heart' and message:
# → Excellent work! The path of a projectile indeed follows a quadratic function.
#
# [Creating] audio\student_6_question_2_0001.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0007.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0002.wav with voice 'am_puck' and message:
# → Excellent. That really solidifies my understanding.
#
# [Creating] audio\teacher_1_question_2_0008.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola.
#
# [Creating] audio\student_2_question_2_0005.wav with voice 'am_puck' and message:
# → Oh, so like when you throw a ball or kick one, it makes that curved shape?
#
# [Creating] audio\teacher_1_question_2_0009.wav with voice 'af_heart' and message:
# → You are describing the shape correctly. Now, what is the specific mathematical function or curve that describes that path? Think of the name of that specific U-shaped curve that is symmetrical.
#
# [Creating] audio\student_3_question_2_0003.wav with voice 'am_puck' and message:
# → That makes a lot of sense. I can really see how a parabola is the perfect mathematical function to describe how a projectile moves.
#
# [Creating] audio\teacher_1_question_2_0010.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_2_0002.wav with voice 'am_puck' and message:
# → I do not know the answer.
#
# [Creating] audio\teacher_1_question_2_0011.wav with voice 'af_heart' and message:
# → The path of a projectile follows a parabolic function. That's all for that question.
#
# [Creating] audio\student_6_question_2_0003.wav with voice 'am_puck' and message:
# → Mmm.
#
# [Creating] audio\teacher_1_question_2_0012.wav with voice 'af_heart' and message:
# → Remember that the path of a projectile is a specific type of symmetrical curve that opens upwards or downwards. What is the name of that mathematical function?
#
# [Creating] audio\student_2_question_2_0006.wav with voice 'am_puck' and message:
# → I think that's called a quadratic function.
#
# [Creating] audio\teacher_1_question_2_0013.wav with voice 'af_heart' and message:
# → You are correct that a quadratic function is used to describe the path. However, the specific mathematical shape of the path itself is known as a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0004.wav with voice 'am_puck' and message:
# → That's a quadratic function, and its graph is a parabola.
#
# [Creating] audio\teacher_1_question_2_0014.wav with voice 'af_heart' and message:
# → Good job.
#
# [Creating] audio\student_6_question_2_0004.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0015.wav with voice 'af_heart' and message:
# → The path of a projectile follows a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0005.wav with voice 'am_puck' and message:
# → Oh, yes! I'm sure it's called a parabola.
#
# [Creating] audio\teacher_1_question_2_0016.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_2_question_2_0007.wav with voice 'am_puck' and message:
# → Alright, thanks.
#
# [Creating] audio\teacher_1_question_2_0017.wav with voice 'af_heart' and message:
# → Remember that the path of a projectile under constant gravity forms a specific type of curve. Think of the type of curve that results from a quadratic equation. What mathematical function does this path follow?
#
# [Creating] audio\student_2_question_2_0008.wav with voice 'am_puck' and message:
# → It follows a quadratic function.
#
# [Creating] audio\teacher_1_question_2_0018.wav with voice 'af_heart' and message:
# → That's a good start, you're on the right track regarding the type of function. Now, consider the specific name of the geometric curve that a quadratic function creates when graphed.
#
# [Creating] audio\student_3_question_2_0006.wav with voice 'am_puck' and message:
# → It follows a parabolic function.
#
# [Creating] audio\teacher_1_question_2_0019.wav with voice 'af_heart' and message:
# → Correct. That's excellent work.
#
# [Creating] audio\student_6_question_2_0005.wav with voice 'am_puck' and message:
# → Uh... I don't know.
#
# [Creating] audio\teacher_1_question_2_0020.wav with voice 'af_heart' and message:
# → Think of the specific curve shape you see when an object is thrown into the air and falls back down under gravity.
#
# [Creating] audio\student_3_question_2_0007.wav with voice 'am_puck' and message:
# → Thank you. I'm ready for the next part.
#
# [Creating] audio\teacher_1_question_2_0021.wav with voice 'af_heart' and message:
# → Okay, let's continue.
#
# What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_2_question_2_0009.wav with voice 'am_puck' and message:
# → Oh, it's like a curved path, right? I think it's called a parabola.
#
# [Creating] audio\teacher_1_question_2_0022.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_3_question_2_0008.wav with voice 'am_puck' and message:
# → Oh, that's a quadratic function!
#
# [Creating] audio\teacher_1_question_2_0023.wav with voice 'af_heart' and message:
# → That's correct! A quadratic function describes the path, and when you graph a quadratic function, the shape you get is a parabola. Good job!
#
# [Creating] audio\student_6_question_2_0006.wav with voice 'am_puck' and message:
# → I don't know
#
# [Creating] audio\teacher_1_question_2_0024.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's it for that item.
#
# [Creating] audio\student_6_question_2_0007.wav with voice 'am_puck' and message:
# → Uh, I don't know.
#
# [Creating] audio\teacher_1_question_2_0025.wav with voice 'af_heart' and message:
# → Think of the shape a ball makes when it is thrown into the air. What mathematical curve does that path resemble?
#
# [Creating] audio\student_2_question_2_0010.wav with voice 'am_puck' and message:
# → Oh, that's like a parabola, right?
#
# [Creating] audio\teacher_1_question_2_0026.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_3_question_2_0009.wav with voice 'am_puck' and message:
# → That path, the one a ball makes, definitely resembles a parabola. I've been thinking about how gravity shapes it.
#
# [Creating] audio\teacher_1_question_2_0027.wav with voice 'af_heart' and message:
# → Correct. That path, the one a ball makes, definitely resembles a parabola. You are right; gravity shapes it into a parabolic trajectory.
#
# [Creating] audio\student_6_question_2_0008.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0028.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's it for that item.
#
# [Creating] audio\student_6_question_2_0009.wav with voice 'am_puck' and message:
# → Uh, I don't know.
#
# [Creating] audio\teacher_1_question_2_0029.wav with voice 'af_heart' and message:
# → Remember that the shape of the path of any object thrown or launched into the air, subject only to gravity, has a specific mathematical curve. What is that curve called?
#
# [Creating] audio\student_2_question_2_0011.wav with voice 'am_puck' and message:
# → Oh, that's a parabola!
#
# [Creating] audio\teacher_1_question_2_0030.wav with voice 'af_heart' and message:
# → Correct!
#
# [Creating] audio\student_3_question_2_0010.wav with voice 'am_puck' and message:
# → Oh, I know this! That curve is called a parabola.
#
# [Creating] audio\teacher_1_question_2_0031.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_2_question_2_0012.wav with voice 'am_puck' and message:
# → Okay. What's next?
#
# [Creating] audio\teacher_1_question_2_0032.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0011.wav with voice 'am_puck' and message:
# → Thank you. I am ready for the next part.
#
# [Creating] audio\teacher_1_question_2_0033.wav with voice 'af_heart' and message:
# → That's all for that question.
#
# [Creating] audio\student_6_question_2_0010.wav with voice 'am_puck' and message:
# → Okay.
#
# [Creating] audio\teacher_1_question_2_0034.wav with voice 'af_heart' and message:
# → What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_6_question_2_0011.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0035.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0013.wav with voice 'am_puck' and message:
# → Okay, so like when you throw a ball, the path it makes is a parabola. Got it.
#
# [Creating] audio\teacher_1_question_2_0036.wav with voice 'af_heart' and message:
# → Correct. The path of a projectile follows a parabolic function. That's all for that question.
#
# [Creating] audio\student_3_question_2_0012.wav with voice 'am_puck' and message:
# → Okay, I understand. That makes sense how the path of a projectile is a parabola.
#
# [Creating] audio\teacher_1_question_2_0037.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_2_0012.wav with voice 'am_puck' and message:
# → Teacher, I don't know the answer.
#
# [Creating] audio\teacher_1_question_2_0038.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0013.wav with voice 'am_puck' and message:
# → I believe it's a quadratic function.
#
# [Creating] audio\teacher_1_question_2_0039.wav with voice 'af_heart' and message:
# → You are correct that it is described by a quadratic function. Think of the specific geometric shape that results from graphing a quadratic equation.
#
# [Creating] audio\student_2_question_2_0014.wav with voice 'am_puck' and message:
# → Okay, so for a quadratic function... is it a parabola? That U-shaped graph?
#
# [Creating] audio\teacher_1_question_2_0040.wav with voice 'af_heart' and message:
# → Correct. A projectile's path follows a parabola.
#
# [Creating] audio\student_2_question_2_0015.wav with voice 'am_puck' and message:
# → Oh, so that's why the path is always curved like that when something flies through the air.
#
# [Creating] audio\teacher_1_question_2_0041.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0016.wav with voice 'am_puck' and message:
# → Oh, so like the arch shape. That makes sense.
#
# [Creating] audio\teacher_1_question_2_0042.wav with voice 'af_heart' and message:
# → That's a good description of the shape! The mathematical function that a path of a projectile follows is a parabola.
#
# [Creating] audio\student_3_question_2_0014.wav with voice 'am_puck' and message:
# → That makes perfect sense, thinking about the arc. I can really visualize that.
#
# [Creating] audio\teacher_1_question_2_0043.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_6_question_2_0013.wav with voice 'am_puck' and message:
# → I don't know the answer.
#
# [Creating] audio\teacher_1_question_2_0044.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. This occurs because the constant force of gravity acts vertically on the projectile, causing it to trace this specific symmetrical curved path.
#
# [Creating] audio\student_3_question_2_0015.wav with voice 'am_puck' and message:
# → That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.
#
# [Creating] audio\teacher_1_question_2_0045.wav with voice 'af_heart' and message:
# → That's correct! The path of a projectile follows a parabola.
#
# [Creating] audio\student_6_question_2_0014.wav with voice 'am_puck' and message:
# → Uh... I don't know.
#
# [Creating] audio\teacher_1_question_2_0046.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0017.wav with voice 'am_puck' and message:
# → Oh, so it makes a curved path, like a parabola.
#
# [Creating] audio\teacher_1_question_2_0047.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_3_question_2_0016.wav with voice 'am_puck' and message:
# → Okay, so the path is a parabola. I've got that down.
#
# [Creating] audio\teacher_1_question_2_0048.wav with voice 'af_heart' and message:
# → Correct. That's all for that question.
#
# [Creating] audio\student_6_question_2_0015.wav with voice 'am_puck' and message:
# → Okay.
#
# [Creating] audio\teacher_1_question_2_0049.wav with voice 'af_heart' and message:
# → What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_3_question_2_0017.wav with voice 'am_puck' and message:
# → Oh, I know! It's a parabola.
#
# [Creating] audio\teacher_1_question_2_0050.wav with voice 'af_heart' and message:
# → Correct!
#
# [Creating] audio\student_6_question_2_0016.wav with voice 'am_puck' and message:
# → Um... I don't know.
#
# [Creating] audio\teacher_1_question_2_0051.wav with voice 'af_heart' and message:
# → Remember that the path of a projectile, like a ball thrown in the air, follows a specific curve. Think of the name of that common mathematical curve.
#
# [Creating] audio\student_2_question_2_0018.wav with voice 'am_puck' and message:
# → Oh, isn't it called a parabola?
#
# [Creating] audio\teacher_1_question_2_0052.wav with voice 'af_heart' and message:
# → Correct.
#
# [Creating] audio\student_2_question_2_0019.wav with voice 'am_puck' and message:
# → Right.
#
# [Creating] audio\teacher_1_question_2_0053.wav with voice 'af_heart' and message:
# → That is not the answer I am looking for. Think of the specific curve shape that describes the path of a projectile under gravity.
#
# [Creating] audio\student_3_question_2_0018.wav with voice 'am_puck' and message:
# → Understood. Thank you. It's good to see I'm on the right track.
#
# [Creating] audio\teacher_1_question_2_0054.wav with voice 'af_heart' and message:
# → Let us continue.
#
# What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_6_question_2_0017.wav with voice 'am_puck' and message:
# → I... I don't know.
#
# [Creating] audio\teacher_1_question_2_0055.wav with voice 'af_heart' and message:
# → The path of a projectile follows a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0019.wav with voice 'am_puck' and message:
# → It's a parabola!
#
# [Creating] audio\teacher_1_question_2_0056.wav with voice 'af_heart' and message:
# → Correct! That's precisely right.
#
# [Creating] audio\student_6_question_2_0018.wav with voice 'am_puck' and message:
# → Umm, I don't know.
#
# [Creating] audio\teacher_1_question_2_0057.wav with voice 'af_heart' and message:
# → Remember that the path of a projectile is a symmetrical curve, often seen in graphs of quadratic equations.
#
# [Creating] audio\student_2_question_2_0020.wav with voice 'am_puck' and message:
# → Okay, so like a curve... a really balanced curve, right?
#
# [Creating] audio\teacher_1_question_2_0058.wav with voice 'af_heart' and message:
# → The path of a projectile follows a parabola.
#
# [Creating] audio\student_3_question_2_0020.wav with voice 'am_puck' and message:
# → Yes, I remember that. The symmetry of the projectile's path really highlights how quadratic equations model real-world motion, which is quite interesting.
#
# [Creating] audio\teacher_1_question_2_0059.wav with voice 'af_heart' and message:
# → The correct mathematical function describing the path of a projectile is a parabola. That's all for that question.
#
# [Creating] audio\student_6_question_2_0019.wav with voice 'am_puck' and message:
# → Uh... it's a symmetrical curve, like from quadratic graphs.
#
# [Creating] audio\teacher_1_question_2_0060.wav with voice 'af_heart' and message:
# → You are on the right track by mentioning a symmetrical curve and quadratic graphs. However, what is the specific mathematical term for that symmetrical curve formed by a quadratic function?
#
# Remember that the graph of a quadratic function creates a unique U-shaped curve.
#
# [Creating] audio\student_6_question_2_0020.wav with voice 'am_puck' and message:
# → I just... I don't know that one.
#
# [Creating] audio\teacher_1_question_2_0061.wav with voice 'af_heart' and message:
# → That's alright. Think of the shape that a ball makes when you throw it up in the air. What mathematical function does that path follow?
#
# [Creating] audio\student_2_question_2_0021.wav with voice 'am_puck' and message:
# → Oh, like the shape it makes? That's a parabola, right? So it would be a quadratic function.
#
# [Creating] audio\teacher_1_question_2_0062.wav with voice 'af_heart' and message:
# → Correct. A projectile's path follows a parabolic trajectory, which is described by a quadratic function. That's all for that question.
#
# [Creating] audio\student_2_question_2_0022.wav with voice 'am_puck' and message:
# → Okay, that makes sense! I'm ready for the next one.
#
# [Creating] audio\teacher_1_question_2_0063.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0023.wav with voice 'am_puck' and message:
# → Okay, got it.
#
# [Creating] audio\teacher_1_question_2_0064.wav with voice 'af_heart' and message:
# → What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_3_question_2_0021.wav with voice 'am_puck' and message:
# → That makes a lot of sense. So, like a ball thrown in the air, its path is always that shape.
#
# [Creating] audio\teacher_1_question_2_0065.wav with voice 'af_heart' and message:
# → That's correct. The mathematical function for a projectile's path is a parabola.
#
# [Creating] audio\student_6_question_2_0021.wav with voice 'am_puck' and message:
# → Uh huh.
#
# [Creating] audio\teacher_1_question_2_0066.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0022.wav with voice 'am_puck' and message:
# → Okay, I understand. I'm ready for the next question.
#
# [Creating] audio\teacher_1_question_2_0067.wav with voice 'af_heart' and message:
# → We are discussing the path of a projectile. What mathematical function does a path of a projectile follow?
#
# [Creating] audio\student_2_question_2_0024.wav with voice 'am_puck' and message:
# → Oh, okay. So when something flies through the air... it makes a curve shape, right? I think that's called a parabola in math.
#
# [Creating] audio\teacher_1_question_2_0068.wav with voice 'af_heart' and message:
# → Correct. That's called a parabola in math.
#
# [Creating] audio\student_3_question_2_0023.wav with voice 'am_puck' and message:
# → The path of a projectile follows a parabolic function. It's really interesting how that shape comes from constant acceleration downwards.
#
# [Creating] audio\teacher_1_question_2_0069.wav with voice 'af_heart' and message:
# → Correct. The path of a projectile follows a parabolic function.
#
# [Creating] audio\student_6_question_2_0022.wav with voice 'am_puck' and message:
# → I don't know, Teacher.
#
# [Creating] audio\teacher_1_question_2_0070.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's it for that item.
#
# [Creating] audio\student_6_question_2_0023.wav with voice 'am_puck' and message:
# → Mhm.
#
# [Creating] audio\teacher_1_question_2_0071.wav with voice 'af_heart' and message:
# → Think of the specific curved shape that objects follow when they are thrown upwards and then fall back down due to gravity.
#
# [Creating] audio\student_2_question_2_0025.wav with voice 'am_puck' and message:
# → Oh, like when you throw a ball? It makes kind of an arc shape, right? Like a curved path.
#
# [Creating] audio\teacher_1_question_2_0072.wav with voice 'af_heart' and message:
# → That's a good description of the path, you're right that it's an arc shape and a curved path. However, the specific mathematical function that a path of a projectile follows is a parabola. That's it for that item.
#
# [Creating] audio\student_3_question_2_0024.wav with voice 'am_puck' and message:
# → Oh, that's an interesting one. I'm thinking about it, and the shape they make is a parabola. It's like a perfect curve, isn't it?
#
# [Creating] audio\teacher_1_question_2_0073.wav with voice 'af_heart' and message:
# → Correct. The path of a projectile follows a parabola.
#
# [Creating] audio\student_6_question_2_0024.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0074.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0025.wav with voice 'am_puck' and message:
# → A parabola. That path follows a quadratic function.
#
# [Creating] audio\teacher_1_question_2_0075.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_6_question_2_0025.wav with voice 'am_puck' and message:
# → Uh, a parabola? So, like, a quadratic function?
#
# [Creating] audio\teacher_1_question_2_0076.wav with voice 'af_heart' and message:
# → Correct. That's all for that question.
#
# [Creating] audio\student_2_question_2_0026.wav with voice 'am_puck' and message:
# → Alright, sounds good. What's next for us?
#
# [Creating] audio\teacher_1_question_2_0077.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0027.wav with voice 'am_puck' and message:
# → So, like a big arc, every time?
#
# [Creating] audio\teacher_1_question_2_0078.wav with voice 'af_heart' and message:
# → The path of a projectile follows a parabola. That's all for that question.
#
# [Creating] audio\student_3_question_2_0026.wav with voice 'am_puck' and message:
# → That's a clear connection between math and physics.
#
# [Creating] audio\teacher_1_question_2_0079.wav with voice 'af_heart' and message:
# → Thank you for sharing your thoughts on the connection, but that is not the specific mathematical function I am looking for. The path of a projectile follows a parabola. That's it for that item.
#
# [Creating] audio\student_6_question_2_0026.wav with voice 'am_puck' and message:
# → I don't know.
#
# [Creating] audio\teacher_1_question_2_0080.wav with voice 'af_heart' and message:
# → Think of the common shape that a thrown object makes as it flies through the air, like a ball thrown upwards. What mathematical curve does that path resemble?
#
# [Creating] audio\student_3_question_2_0027.wav with voice 'am_puck' and message:
# → Okay.
#
# [Creating] audio\teacher_1_question_2_0081.wav with voice 'af_heart' and message:
# → What mathematical function does the path of a projectile follow?
#
# [Creating] audio\student_2_question_2_0028.wav with voice 'am_puck' and message:
# → Oh, isn't that a parabola?
#
# [Creating] audio\teacher_1_question_2_0082.wav with voice 'af_heart' and message:
# → That's correct!
#
# [Creating] audio\student_3_question_2_0028.wav with voice 'am_puck' and message:
# → The path of a projectile follows a parabolic function. It's really interesting how that shape relates to quadratic equations in math.
#
# [Creating] audio\teacher_1_question_2_0083.wav with voice 'af_heart' and message:
# → Excellent work!
#
# [Creating] audio\student_6_question_2_0027.wav with voice 'am_puck' and message:
# → I don't know, teacher. I just can't think of it right now.
#
# [Creating] audio\teacher_1_question_2_0084.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola.
#
# [Creating] audio\student_6_question_2_0028.wav with voice 'am_puck' and message:
# → Mhm.
#
# [Creating] audio\teacher_1_question_2_0085.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's all for that question.
#
# [Creating] audio\student_2_question_2_0029.wav with voice 'am_puck' and message:
# → Okay, so it's a parabola. Got it.
#
# [Creating] audio\teacher_1_question_2_0086.wav with voice 'af_heart' and message:
# → Correct. That's all for that question.
#
# [Creating] audio\student_3_question_2_0029.wav with voice 'am_puck' and message:
# → Oh, that's really interesting. So it's always a curve like that when something is thrown or shot.
#
# [Creating] audio\teacher_1_question_2_0087.wav with voice 'af_heart' and message:
# → While it is indeed a curve, can you recall the specific mathematical function that describes the path of a projectile? The path of a projectile follows a parabola. That's all for that question.
#
# [Creating] audio\student_6_question_2_0029.wav with voice 'am_puck' and message:
# → Ugh. I don't know.
#
# [Creating] audio\teacher_1_question_2_0088.wav with voice 'af_heart' and message:
# → The mathematical function that a path of a projectile follows is a parabola. That's it for that item.
#
# [Creating] audio\teacher_1_question_3_0001.wav with voice 'af_heart' and message:
# → Good day! Let's work through this together. Can you identify everyday situations where we can observe projectile motion?
#
# [Creating] audio\student_2_question_3_0001.wav with voice 'am_puck' and message:
# → Hey, um, when you throw a ball, like a basketball or something. And maybe like, water spraying from a fountain?
#
# [Creating] audio\teacher_1_question_3_0002.wav with voice 'af_heart' and message:
# → Good job, that's correct! Throwing a basketball is an excellent example of projectile motion in everyday life.
#
# [Creating] audio\student_3_question_3_0001.wav with voice 'am_puck' and message:
# → Good day! Yes, I can. We see it a lot, like when someone throws a basketball, or when a soccer player kicks a ball. Even water coming out of a garden hose shows it.
#
# [Creating] audio\teacher_1_question_3_0003.wav with voice 'af_heart' and message:
# → Excellent, you've provided several clear examples of projectile motion in everyday life. Good job! That's it for that item.
#
# [Creating] audio\student_6_question_3_0001.wav with voice 'am_puck' and message:
# → I... I don't know. My mind's kind of blank right now.
#
# [Creating] audio\teacher_1_question_3_0004.wav with voice 'af_heart' and message:
# → That's perfectly alright. Sometimes our minds draw a blank.
#
# Think of sports where an object is thrown or kicked into the air. Can you think of any examples where an object follows a curved path through the air?
#
# Audio generation completed.

# %% [markdown]
# ## Step 3: Audio Link Integration
#
# After generating the audio files, you need to upload them to a Hugging Face dataset repository to make them publicly accessible.
#
# ### Manual Upload Process:
# 1. **Upload audio files** to a Hugging Face dataset repository
# 2. **Preserve filenames** - ensure the uploaded files keep their original names
# 3. **Update the base URL** in the code below to match your repository
# 4. **Run the integration code** to add download links to the conversation tree
#
# ### What the integration code does:
# - **Adds audio links**: Inserts download URLs for each tagged dialogue turn
# - **Preserves structure**: Maintains the original conversation tree hierarchy
# - **Creates enhanced JSON**: Outputs a new file with embedded audio links
# - **Uses direct download URLs**: Links include `?download=true` for immediate access

# %%
# Get HF dataset URL from user input
dataset_url = input("Enter your Hugging Face dataset URL (e.g. https://huggingface.co/datasets/your-username/your-dataset-name): ")
HF_BASE_URL = f"{dataset_url}/resolve/main"

with open("conversation-tree.json", "r", encoding="utf-8") as f:
    data = json.load(f)

def add_audio_link_by_tag(node):
    if isinstance(node, dict):
        tag = node.get("tag", "").strip()
        if tag:
            audio_url = f"{HF_BASE_URL}/{tag}.wav?download=true"

            new_node = {}
            for k, v in node.items():
                new_node[k] = v
                if k == "tag":
                    new_node["audio link"] = audio_url
            node.clear()
            node.update(new_node)

        # Recurse through nested nodes
        for field in ("children", "responses"):
            if field in node:
                for child in node[field]:
                    add_audio_link_by_tag(child)

# Apply the function to each root question
for q in data.get("questions", []):
    add_audio_link_by_tag(q)

# Save the result
output_path = "conversation-tree-with-audio.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(data, f, indent=2, ensure_ascii=False)

print(f"Audio links inserted after tag and saved to: {output_path}")
# Out:
# Audio links inserted after tag and saved to: conversation-tree-with-audio.json
