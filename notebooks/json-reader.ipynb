# %% [markdown]
# ### This notebook is used while developing the json parser that will build the prompt for Gemma.

# %%
import json

# Preload the JSON data at module level
try:
    with open("../data/conversation-tree-v2.json", 'r', encoding='utf-8') as file:
        JSON_DATA = json.load(file)
except FileNotFoundError:
    print("❌ Error: File 'conversation-tree-simplified-with-audio.json' not found.")
    JSON_DATA = {}
except json.JSONDecodeError as e:
    print(f"❌ Error: Invalid JSON format - {e}")
    JSON_DATA = {}
except Exception as e:
    print(f"❌ Error: {e}")
    JSON_DATA = {}

# %%
def get_question(speaker_name, index=0):
    """
    Return message and audio for a speaker from the first level of questions.
    
    Args:
        speaker_name (str): Name of the speaker (e.g., 'student_1', 'teacher_1')
    
    Returns:
        dict: Dictionary containing 'message' and 'audio' for the speaker
    """
    results = []
    
    if 'questions' in JSON_DATA:
        initial_question = JSON_DATA['questions'][index]
        for question in initial_question['children']:
            print(question.get('speaker'))
            if question.get('speaker') == speaker_name:
                result = {
                    'message': question.get('message', ''),
                    'question': initial_question.get('message', ''),
                    'criteria': initial_question.get('criteria', ''),
                    'audio': question.get('audio link', ''),
                    'responses': question.get('responses', [])
                }
                return result
    return {
        'message':'Speaker not found',
        'audio': ''
    }

get_question("teacher_1",0)
# Out:
# teacher_1
# {'message': "Good morning! Let's explore this together. In the context of projectile motion, how would you define a projectile?",
#  'question': 'Within the topic of projectile motion, how would you describe a projectile?',
#  'criteria': '',
#  'audio': 'voice/teacher_1_question_1_0001.wav',
#  'responses': [{'speaker': 'student_2',
#    'message': "Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.",
#    'tag': 'student_2_question_1_0001',
#    'audio link': 'voice/student_2_question_1_0001.wav',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.',
#      'tag': 'teacher_1_question_1_0002',
#      'audio link': 'voice/teacher_1_question_1_0002.wav',
#      'responses': [{'speaker': 'student_2',
#        'message': "Okay, so it's mainly about gravity then, for the ideal one.",
#        'tag': 'student_2_question_1_0002',
#        'audio link': 'voice/student_2_question_1_0002.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?",
#          'tag': 'teacher_1_question_1_0003',
#          'audio link': 'voice/teacher_1_question_1_0003.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.",
#            'tag': 'student_2_question_1_0003',
#            'audio link': 'voice/student_2_question_1_0003.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0004',
#              'audio link': 'voice/teacher_1_question_1_0004.wav',
#              'responses': []}]},
#           {'speaker': 'student_3',
#            'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.',
#            'tag': 'student_3_question_1_0001',
#            'audio link': 'voice/student_3_question_1_0001.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0005',
#              'audio link': 'voice/teacher_1_question_1_0005.wav',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "I don't know.",
#            'tag': 'student_6_question_1_0001',
#            'audio link': 'voice/student_6_question_1_0001.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.',
#              'tag': 'teacher_1_question_1_0006',
#              'audio link': 'voice/teacher_1_question_1_0006.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.',
#                'tag': 'student_2_question_1_0004',
#                'audio link': 'voice/student_2_question_1_0004.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0007',
#                  'audio link': 'voice/teacher_1_question_1_0007.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is any object that's thrown or launched into the air. Once it's moving, the primary force that pulls it back down is gravity.",
#                'tag': 'student_3_question_1_0002',
#                'audio link': 'voice/student_3_question_1_0002.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0008',
#                  'audio link': 'voice/teacher_1_question_1_0008.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0002',
#                'audio link': 'voice/student_6_question_1_0002.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of an object that is launched or thrown, and remember that its path through the air is mainly determined by a specific natural force. Now, how would you describe a projectile?',
#                  'tag': 'teacher_1_question_1_0009',
#                  'audio link': 'voice/teacher_1_question_1_0009.wav',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Yes, I see, Teacher. So, for the ideal definition, the focus is just on gravity, and other forces like air resistance aren't considered. That makes a lot of sense for simplifying the concept. I'm ready.",
#        'tag': 'student_3_question_1_0003',
#        'audio link': 'voice/student_3_question_1_0003.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Within the topic of projectile motion, how would you describe a projectile?',
#          'tag': 'teacher_1_question_1_0010',
#          'audio link': 'voice/teacher_1_question_1_0010.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': 'A projectile is like anything that gets launched or thrown into the air.',
#            'tag': 'student_2_question_1_0005',
#            'audio link': 'voice/student_2_question_1_0005.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've mentioned that a projectile is an object launched or thrown into the air, which is a good start. However, your definition is not yet complete. Think of the primary force that acts on the object once it is in the air.",
#              'tag': 'teacher_1_question_1_0011',
#              'audio link': 'voice/teacher_1_question_1_0011.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, okay! So it's about the force that pulls it down, right? Like gravity?",
#                'tag': 'student_2_question_1_0006',
#                'audio link': 'voice/student_2_question_1_0006.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are correct that gravity is a crucial part of it. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0012',
#                  'audio link': 'voice/teacher_1_question_1_0012.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So, a projectile is an object launched or thrown into the air, and once it's in the air, the only significant force acting on it is gravity.",
#                'tag': 'student_3_question_1_0004',
#                'audio link': 'voice/student_3_question_1_0004.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0013',
#                  'audio link': 'voice/teacher_1_question_1_0013.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0003',
#                'audio link': 'voice/student_6_question_1_0003.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Within the topic of projectile motion, how would you describe a projectile? You mentioned you don't know.\n\nThink of an object that is launched into the air, and consider the primary force that acts upon it once it's in flight.",
#                  'tag': 'teacher_1_question_1_0014',
#                  'audio link': 'voice/teacher_1_question_1_0014.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "A projectile is an object that's launched or thrown into the air, and then the only force acting on it is gravity. We typically ignore air resistance in this context. It's really interesting how it follows that curved path!",
#            'tag': 'student_3_question_1_0005',
#            'audio link': 'voice/student_3_question_1_0005.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0015',
#              'audio link': 'voice/teacher_1_question_1_0015.wav',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Uh, I don't know.",
#            'tag': 'student_6_question_1_0004',
#            'audio link': 'voice/student_6_question_1_0004.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that a projectile is an object that is set in motion and then moves only under a specific natural force. Now, how would you describe a projectile?',
#              'tag': 'teacher_1_question_1_0016',
#              'audio link': 'voice/teacher_1_question_1_0016.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it's like when you throw something, or like a ball you kick, and then gravity just takes it over?",
#                'tag': 'student_2_question_1_0007',
#                'audio link': 'voice/student_2_question_1_0007.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good Job! That's it for that item.",
#                  'tag': 'teacher_1_question_1_0017',
#                  'audio link': 'voice/teacher_1_question_1_0017.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, so a projectile is an object that's set in motion and then, once it's moving, the only natural force acting on it is gravity.",
#                'tag': 'student_3_question_1_0006',
#                'audio link': 'voice/student_3_question_1_0006.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good attempt, but let's refine it to be more precise. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0018',
#                  'audio link': 'voice/teacher_1_question_1_0018.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'I dunno',
#                'tag': 'student_6_question_1_0005',
#                'audio link': 'voice/student_6_question_1_0005.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0019',
#                  'audio link': 'voice/teacher_1_question_1_0019.wav',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_6',
#        'message': "Uh... I don't know.",
#        'tag': 'student_6_question_1_0006',
#        'audio link': 'voice/student_6_question_1_0006.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air.",
#          'tag': 'teacher_1_question_1_0020',
#          'audio link': 'voice/teacher_1_question_1_0020.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': "It's gravity, right? That's the main one pulling things down.",
#            'tag': 'student_2_question_1_0008',
#            'audio link': 'voice/student_2_question_1_0008.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Your answer correctly identifies gravity as a key factor. However, the definition of a projectile also involves how the object is initially set into motion. Think of how a projectile begins its movement. How is it typically put into the air?',
#              'tag': 'teacher_1_question_1_0021',
#              'audio link': 'voice/teacher_1_question_1_0021.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh right. It's usually thrown or launched into the air.",
#                'tag': 'student_2_question_1_0009',
#                'audio link': 'voice/student_2_question_1_0009.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0022',
#                  'audio link': 'voice/teacher_1_question_1_0022.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So, a projectile is also something that's given an initial push or throw, or launched into the air. Like, it's not just sitting there, it starts with a force.",
#                'tag': 'student_3_question_1_0007',
#                'audio link': 'voice/student_3_question_1_0007.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good start, but to be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0023',
#                  'audio link': 'voice/teacher_1_question_1_0023.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I'm not sure.",
#                'tag': 'student_6_question_1_0007',
#                'audio link': 'voice/student_6_question_1_0007.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0024',
#                  'audio link': 'voice/teacher_1_question_1_0024.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Okay, I understand. Once a projectile is in the air, the primary force acting on it is gravity. It's always pulling it downwards, which makes sense because everything eventually falls.",
#            'tag': 'student_3_question_1_0008',
#            'audio link': 'voice/student_3_question_1_0008.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've correctly identified that gravity is a primary force acting on a projectile once it's in the air. However, to fully describe a projectile, consider what kind of object it is and how it initially gets into motion.\n\nTry to imagine what kind of object we are discussing and how it begins its movement into the air.",
#              'tag': 'teacher_1_question_1_0025',
#              'audio link': 'voice/teacher_1_question_1_0025.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it's like, anything that gets thrown or launched? Like a baseball? And it starts moving because something pushes it really hard, like when you throw it.",
#                'tag': 'student_2_question_1_0010',
#                'audio link': 'voice/student_2_question_1_0010.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are close! You correctly identified that it's anything that gets thrown or launched. However, a projectile is more precisely defined as any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0026',
#                  'audio link': 'voice/teacher_1_question_1_0026.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is an object that's launched or thrown into the air, and it gets its initial motion from that push or force that sends it off.",
#                'tag': 'student_3_question_1_0009',
#                'audio link': 'voice/student_3_question_1_0009.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You're very close! You correctly identified that a projectile is an object launched or thrown. However, a key part of the definition is what continues to influence its motion once it's in the air.\n\nA projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.",
#                  'tag': 'teacher_1_question_1_0027',
#                  'audio link': 'voice/teacher_1_question_1_0027.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I... I don't really know.",
#                'tag': 'student_6_question_1_0008',
#                'audio link': 'voice/student_6_question_1_0008.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0028',
#                  'audio link': 'voice/teacher_1_question_1_0028.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "I don't know.",
#            'tag': 'student_6_question_1_0009',
#            'audio link': 'voice/student_6_question_1_0009.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Try to imagine an object that has been launched into the air, and consider the primary force that acts upon it during its flight.',
#              'tag': 'teacher_1_question_1_0029',
#              'audio link': 'voice/teacher_1_question_1_0029.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Hmm okay, an object launched into the air. So it goes up, and then it comes back down, right? I guess the main force acting on it would be gravity.',
#                'tag': 'student_2_question_1_0011',
#                'audio link': 'voice/student_2_question_1_0011.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0030',
#                  'audio link': 'voice/teacher_1_question_1_0030.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, that's an interesting thought experiment! The primary force acting on it would definitely be gravity.",
#                'tag': 'student_3_question_1_0010',
#                'audio link': 'voice/student_3_question_1_0010.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0031',
#                  'audio link': 'voice/teacher_1_question_1_0031.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uhm, I don't know.",
#                'tag': 'student_6_question_1_0010',
#                'audio link': 'voice/student_6_question_1_0010.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Remember that a projectile is an object initially set into motion and then moves predominantly under a single natural force.',
#                  'tag': 'teacher_1_question_1_0032',
#                  'audio link': 'voice/teacher_1_question_1_0032.wav',
#                  'responses': []}]}]}]}]}]}]}]},
#   {'speaker': 'student_3',
#    'message': "Good morning, teacher! I've really been focusing on this topic. From my understanding, a projectile is any object that's launched or thrown into the air, and then, once it's moving, the only important force acting on it is gravity.",
#    'tag': 'student_3_question_1_0011',
#    'audio link': 'voice/student_3_question_1_0011.wav',
#    'responses': [{'speaker': 'teacher_1',
#      'message': "That's correct!",
#      'tag': 'teacher_1_question_1_0033',
#      'audio link': 'voice/teacher_1_question_1_0033.wav',
#      'responses': []}]},
#   {'speaker': 'student_6',
#    'message': "Um, I don't know.",
#    'tag': 'student_6_question_1_0011',
#    'audio link': 'voice/student_6_question_1_0011.wav',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of how you would make something fly through the air.',
#      'tag': 'teacher_1_question_1_0034',
#      'audio link': 'voice/teacher_1_question_1_0034.wav',
#      'responses': [{'speaker': 'student_2',
#        'message': "Oh, a projectile? It's basically anything that gets thrown or launched into the air, and then it just keeps going.",
#        'tag': 'student_2_question_1_0012',
#        'audio link': 'voice/student_2_question_1_0012.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Your description is close, but it is incomplete. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#          'tag': 'teacher_1_question_1_0035',
#          'audio link': 'voice/teacher_1_question_1_0035.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Okay, I get it. So, gravity is the main thing that keeps it going.',
#            'tag': 'student_2_question_1_0013',
#            'audio link': 'voice/student_2_question_1_0013.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've correctly identified that gravity is a key factor. However, the definition of a projectile also describes how it begins its motion.\n\nRemember that a projectile needs an initial push or throw to start its journey. Please try to describe a projectile again, keeping both its initial motion and the influence of gravity in mind.",
#              'tag': 'teacher_1_question_1_0036',
#              'audio link': 'voice/teacher_1_question_1_0036.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, so a projectile is like something you throw or kick, and then gravity pulls it down as it flies through the air.',
#                'tag': 'student_2_question_1_0014',
#                'audio link': 'voice/student_2_question_1_0014.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good job. That's a very good description of a projectile.",
#                  'tag': 'teacher_1_question_1_0037',
#                  'audio link': 'voice/teacher_1_question_1_0037.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'Okay, so a projectile is an object that gets an initial push or throw, and then the only thing affecting its movement is gravity.',
#                'tag': 'student_3_question_1_0012',
#                'audio link': 'voice/student_3_question_1_0012.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good job. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0038',
#                  'audio link': 'voice/teacher_1_question_1_0038.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh, it's something that gets like, an initial push or throw, and then only gravity affects it.",
#                'tag': 'student_6_question_1_0012',
#                'audio link': 'voice/student_6_question_1_0012.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0039',
#                  'audio link': 'voice/teacher_1_question_1_0039.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Okay, so it's any object set in motion through the air, and then only gravity acts on it. Got it! That makes it clearer.",
#            'tag': 'student_3_question_1_0013',
#            'audio link': 'voice/student_3_question_1_0013.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0040',
#              'audio link': 'voice/teacher_1_question_1_0040.wav',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': 'Right.',
#            'tag': 'student_6_question_1_0013',
#            'audio link': 'voice/student_6_question_1_0013.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#              'tag': 'teacher_1_question_1_0041',
#              'audio link': 'voice/teacher_1_question_1_0041.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, makes sense.',
#                'tag': 'student_2_question_1_0015',
#                'audio link': 'voice/student_2_question_1_0015.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0042',
#                  'audio link': 'voice/teacher_1_question_1_0042.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, I understand. So it's just about gravity once it's in the air. Got it.",
#                'tag': 'student_3_question_1_0014',
#                'audio link': 'voice/student_3_question_1_0014.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.',
#                  'tag': 'teacher_1_question_1_0043',
#                  'audio link': 'voice/teacher_1_question_1_0043.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Uh-huh.',
#                'tag': 'student_6_question_1_0014',
#                'audio link': 'voice/student_6_question_1_0014.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0044',
#                  'audio link': 'voice/teacher_1_question_1_0044.wav',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Okay, so a projectile... thinking about how something flies through the air, it's basically any object that's been thrown, shot, or launched into space. And then, once it's moving, the only main force affecting its path is gravity, you know, pulling it downwards. That's how I'd describe it.",
#        'tag': 'student_3_question_1_0015',
#        'audio link': 'voice/student_3_question_1_0015.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Your description is mostly accurate, highlighting the object being set in motion and gravity as the sole influence. However, consider the specific medium in which typical projectile motion occurs.\n\nThink of the environment where a projectile moves when we study it in physics.',
#          'tag': 'teacher_1_question_1_0045',
#          'audio link': 'voice/teacher_1_question_1_0045.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Hmm, so like, the air around it?',
#            'tag': 'student_2_question_1_0016',
#            'audio link': 'voice/student_2_question_1_0016.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that a projectile is an object that is set into motion. Think of the specific force that acts upon this object once it is moving through the air, completely independent of its initial push.',
#              'tag': 'teacher_1_question_1_0046',
#              'audio link': 'voice/teacher_1_question_1_0046.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Hmm, so after it's been pushed, the force that's always there... is it gravity?",
#                'tag': 'student_2_question_1_0017',
#                'audio link': 'voice/student_2_question_1_0017.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are correct that gravity is the force involved. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0047',
#                  'audio link': 'voice/teacher_1_question_1_0047.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "That would be the force of gravity. It's the continuous downward pull on the object, completely independent of its initial push.",
#                'tag': 'student_3_question_1_0016',
#                'audio link': 'voice/student_3_question_1_0016.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0048',
#                  'audio link': 'voice/teacher_1_question_1_0048.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'I dunno.',
#                'tag': 'student_6_question_1_0015',
#                'audio link': 'voice/student_6_question_1_0015.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0049',
#                  'audio link': 'voice/teacher_1_question_1_0049.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': 'Oh, I see what you mean! When we talk about typical projectile motion, the object is usually moving through the air. So, air resistance would also be a factor, even if we sometimes simplify problems by neglecting it.',
#            'tag': 'student_3_question_1_0017',
#            'audio link': 'voice/student_3_question_1_0017.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Your understanding of air resistance as a factor in real-world scenarios is correct. However, for the definition of an ideal projectile in physics, we often simplify the forces involved.\n\nThink about the action that starts an object on a projectile path and the fundamental natural force that continuously acts upon it as it travels through the air.',
#              'tag': 'teacher_1_question_1_0050',
#              'audio link': 'voice/teacher_1_question_1_0050.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Okay, so for an ideal projectile, it starts with like, an initial push or launch, right? And then it's just gravity pulling it down the whole time?",
#                'tag': 'student_2_question_1_0018',
#                'audio link': 'voice/student_2_question_1_0018.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct. That is a good description of a projectile.',
#                  'tag': 'teacher_1_question_1_0051',
#                  'audio link': 'voice/teacher_1_question_1_0051.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So for an ideal projectile, we're simplifying things. The action that starts it is its initial velocity, and the only continuous force acting on it would be gravity.",
#                'tag': 'student_3_question_1_0018',
#                'audio link': 'voice/student_3_question_1_0018.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! Good job.",
#                  'tag': 'teacher_1_question_1_0052',
#                  'audio link': 'voice/teacher_1_question_1_0052.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Um... just gravity, I guess?',
#                'tag': 'student_6_question_1_0016',
#                'audio link': 'voice/student_6_question_1_0016.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0053',
#                  'audio link': 'voice/teacher_1_question_1_0053.wav',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "Um... it's usually in the air, right? But sometimes we just ignore the air part for the problems.",
#            'tag': 'student_6_question_1_0017',
#            'audio link': 'voice/student_6_question_1_0017.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You are close, but let's refine that definition. Think of how the object begins its journey and what primary force acts upon it once it's moving through the air.",
#              'tag': 'teacher_1_question_1_0054',
#              'audio link': 'voice/teacher_1_question_1_0054.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it starts off with like, an initial push, right? And then gravity is the main thing pulling it down while it's in the air?",
#                'tag': 'student_2_question_1_0019',
#                'audio link': 'voice/student_2_question_1_0019.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! You've accurately described a projectile.",
#                  'tag': 'teacher_1_question_1_0055',
#                  'audio link': 'voice/teacher_1_question_1_0055.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, I think I see what you mean. So, it starts when something is launched or thrown, and then the main force acting on it while it's in the air is gravity, pulling it downwards.",
#                'tag': 'student_3_question_1_0019',
#                'audio link': 'voice/student_3_question_1_0019.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! A projectile is indeed an object that is launched or thrown, and its motion through the air is primarily influenced by gravity.",
#                  'tag': 'teacher_1_question_1_0056',
#                  'audio link': 'voice/teacher_1_question_1_0056.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh... I guess it's when something gets, like, thrown, and then gravity just pulls it down while it's in the air?",
#                'tag': 'student_6_question_1_0018',
#                'audio link': 'voice/student_6_question_1_0018.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0057',
#                  'audio link': 'voice/teacher_1_question_1_0057.wav',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_6',
#        'message': "I don't know.",
#        'tag': 'student_6_question_1_0019',
#        'audio link': 'voice/student_6_question_1_0019.wav',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Think of an object that is set in motion through the air, and what the only significant force acting upon it is once it's moving freely. What would you call such an object?",
#          'tag': 'teacher_1_question_1_0058',
#          'audio link': 'voice/teacher_1_question_1_0058.wav',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Hmm, like a baseball thrown in the air? I guess gravity would be the main force pulling it down. And... what do you call it? Is it a projectile?',
#            'tag': 'student_2_question_1_0020',
#            'audio link': 'voice/student_2_question_1_0020.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct! A projectile is indeed any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.",
#              'tag': 'teacher_1_question_1_0059',
#              'audio link': 'voice/teacher_1_question_1_0059.wav',
#              'responses': []}]},
#           {'speaker': 'student_3',
#            'message': "Oh, I've got this! So, if an object is set in motion through the air, like a basketball shot, the only significant force acting on it once it's freely moving is gravity. We would call that object a projectile.",
#            'tag': 'student_3_question_1_0020',
#            'audio link': 'voice/student_3_question_1_0020.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0060',
#              'audio link': 'voice/teacher_1_question_1_0060.wav',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Uh, I don't know.",
#            'tag': 'student_6_question_1_0020',
#            'audio link': 'voice/student_6_question_1_0020.wav',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Within the topic of projectile motion, how would you describe a projectile?',
#              'tag': 'teacher_1_question_1_0061',
#              'audio link': 'voice/teacher_1_question_1_0061.wav',
#              'responses': [{'speaker': 'student_2',
#                'message': "Hmm, a projectile? I guess it's basically anything that gets thrown or launched into the air.",
#                'tag': 'student_2_question_1_0021',
#                'audio link': 'voice/student_2_question_1_0021.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'You are correct that a projectile is anything that gets thrown or launched into the air. To be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.',
#                  'tag': 'teacher_1_question_1_0062',
#                  'audio link': 'voice/teacher_1_question_1_0062.wav',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is essentially any object that's launched or thrown, and then its only significant force acting on it is gravity. We usually simplify it by not considering air resistance in our initial studies.",
#                'tag': 'student_3_question_1_0021',
#                'audio link': 'voice/student_3_question_1_0021.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! You have accurately described a projectile.",
#                  'tag': 'teacher_1_question_1_0063',
#                  'audio link': 'voice/teacher_1_question_1_0063.wav',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0021',
#                'audio link': 'voice/student_6_question_1_0021.wav',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0064',
#                  'audio link': 'voice/teacher_1_question_1_0064.wav',
#                  'responses': []}]}]}]}]}]}]}]}]}

# %%
len(JSON_DATA['questions'])
# Out:
# 3

# %%
get_question("teacher_1",1)
# Out:
# teacher_1
# {'message': "Hi there! I'd like you to think about something. What mathematical function describes the path of a projectile?",
#  'question': 'What mathematical function does a path of a projectile follow?',
#  'criteria': '',
#  'audio': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0001.wav?download=true',
#  'responses': [{'speaker': 'student_2',
#    'message': 'Oh, is it a quadratic function?',
#    'tag': 'student_2_question_2_0001',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0001.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'You are very close! A quadratic function does describe the path. Now, think of the specific geometric shape that the graph of a quadratic function creates. What is that shape called?',
#      'tag': 'teacher_1_question_2_0002',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0002.wav?download=true',
#      'responses': [{'speaker': 'student_2',
#        'message': "Oh, I remember that! It's called a parabola, right?",
#        'tag': 'student_2_question_2_0002',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0002.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Correct.',
#          'tag': 'teacher_1_question_2_0003',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0003.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Okay, cool!',
#            'tag': 'student_2_question_2_0003',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0003.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'What mathematical function does a path of a projectile follow?',
#              'tag': 'teacher_1_question_2_0004',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0004.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, it's that curve shape, like a parabola. So, it's a quadratic function, right?",
#                'tag': 'student_2_question_2_0004',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0004.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! The path of a projectile follows a parabola, which is represented by a quadratic function.",
#                  'tag': 'teacher_1_question_2_0005',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0005.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'It follows a quadratic function!',
#                'tag': 'student_3_question_2_0001',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0001.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Excellent work! The path of a projectile indeed follows a quadratic function.',
#                  'tag': 'teacher_1_question_2_0006',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0006.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_2_0001',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0001.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0007',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0007.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': 'Excellent. That really solidifies my understanding.',
#            'tag': 'student_3_question_2_0002',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0002.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'The mathematical function that a path of a projectile follows is a parabola.',
#              'tag': 'teacher_1_question_2_0008',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0008.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Oh, so like when you throw a ball or kick one, it makes that curved shape?',
#                'tag': 'student_2_question_2_0005',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0005.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'You are describing the shape correctly. Now, what is the specific mathematical function or curve that describes that path? Think of the name of that specific U-shaped curve that is symmetrical.',
#                  'tag': 'teacher_1_question_2_0009',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0009.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'That makes a lot of sense. I can really see how a parabola is the perfect mathematical function to describe how a projectile moves.',
#                'tag': 'student_3_question_2_0003',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0003.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_2_0010',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0010.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'I do not know the answer.',
#                'tag': 'student_6_question_2_0002',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0002.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The path of a projectile follows a parabolic function. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0011',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0011.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': 'Mmm.',
#            'tag': 'student_6_question_2_0003',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0003.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that the path of a projectile is a specific type of symmetrical curve that opens upwards or downwards. What is the name of that mathematical function?',
#              'tag': 'teacher_1_question_2_0012',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0012.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "I think that's called a quadratic function.",
#                'tag': 'student_2_question_2_0006',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0006.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are correct that a quadratic function is used to describe the path. However, the specific mathematical shape of the path itself is known as a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0013',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0013.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "That's a quadratic function, and its graph is a parabola.",
#                'tag': 'student_3_question_2_0004',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0004.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Good job.',
#                  'tag': 'teacher_1_question_2_0014',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0014.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_2_0004',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0004.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The path of a projectile follows a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0015',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0015.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Oh, yes! I'm sure it's called a parabola.",
#        'tag': 'student_3_question_2_0005',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0005.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Correct.',
#          'tag': 'teacher_1_question_2_0016',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0016.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Alright, thanks.',
#            'tag': 'student_2_question_2_0007',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0007.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that the path of a projectile under constant gravity forms a specific type of curve. Think of the type of curve that results from a quadratic equation. What mathematical function does this path follow?',
#              'tag': 'teacher_1_question_2_0017',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0017.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'It follows a quadratic function.',
#                'tag': 'student_2_question_2_0008',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0008.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good start, you're on the right track regarding the type of function. Now, consider the specific name of the geometric curve that a quadratic function creates when graphed.",
#                  'tag': 'teacher_1_question_2_0018',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0018.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'It follows a parabolic function.',
#                'tag': 'student_3_question_2_0006',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0006.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's excellent work.",
#                  'tag': 'teacher_1_question_2_0019',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0019.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh... I don't know.",
#                'tag': 'student_6_question_2_0005',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0005.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Think of the specific curve shape you see when an object is thrown into the air and falls back down under gravity.',
#                  'tag': 'teacher_1_question_2_0020',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0020.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Thank you. I'm ready for the next part.",
#            'tag': 'student_3_question_2_0007',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0007.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "Okay, let's continue.\n\nWhat mathematical function does a path of a projectile follow?",
#              'tag': 'teacher_1_question_2_0021',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0021.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, it's like a curved path, right? I think it's called a parabola.",
#                'tag': 'student_2_question_2_0009',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0009.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct.',
#                  'tag': 'teacher_1_question_2_0022',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0022.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, that's a quadratic function!",
#                'tag': 'student_3_question_2_0008',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0008.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! A quadratic function describes the path, and when you graph a quadratic function, the shape you get is a parabola. Good job!",
#                  'tag': 'teacher_1_question_2_0023',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0023.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know",
#                'tag': 'student_6_question_2_0006',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0006.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0024',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0024.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "Uh, I don't know.",
#            'tag': 'student_6_question_2_0007',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0007.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Think of the shape a ball makes when it is thrown into the air. What mathematical curve does that path resemble?',
#              'tag': 'teacher_1_question_2_0025',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0025.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, that's like a parabola, right?",
#                'tag': 'student_2_question_2_0010',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0010.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct.',
#                  'tag': 'teacher_1_question_2_0026',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0026.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "That path, the one a ball makes, definitely resembles a parabola. I've been thinking about how gravity shapes it.",
#                'tag': 'student_3_question_2_0009',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0009.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct. That path, the one a ball makes, definitely resembles a parabola. You are right; gravity shapes it into a parabolic trajectory.',
#                  'tag': 'teacher_1_question_2_0027',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0027.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_2_0008',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0008.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0028',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0028.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_6',
#        'message': "Uh, I don't know.",
#        'tag': 'student_6_question_2_0009',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0009.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Remember that the shape of the path of any object thrown or launched into the air, subject only to gravity, has a specific mathematical curve. What is that curve called?',
#          'tag': 'teacher_1_question_2_0029',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0029.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Oh, that's a parabola!",
#            'tag': 'student_2_question_2_0011',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0011.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Correct!',
#              'tag': 'teacher_1_question_2_0030',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0030.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_3',
#            'message': 'Oh, I know this! That curve is called a parabola.',
#            'tag': 'student_3_question_2_0010',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0010.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Correct.',
#              'tag': 'teacher_1_question_2_0031',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0031.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Okay. What's next?",
#                'tag': 'student_2_question_2_0012',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0012.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0032',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0032.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'Thank you. I am ready for the next part.',
#                'tag': 'student_3_question_2_0011',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0011.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's all for that question.",
#                  'tag': 'teacher_1_question_2_0033',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0033.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Okay.',
#                'tag': 'student_6_question_2_0010',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0010.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'What mathematical function does a path of a projectile follow?',
#                  'tag': 'teacher_1_question_2_0034',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0034.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "I don't know.",
#            'tag': 'student_6_question_2_0011',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0011.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0035',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0035.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, so like when you throw a ball, the path it makes is a parabola. Got it.',
#                'tag': 'student_2_question_2_0013',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0013.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. The path of a projectile follows a parabolic function. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0036',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0036.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'Okay, I understand. That makes sense how the path of a projectile is a parabola.',
#                'tag': 'student_3_question_2_0012',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0012.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_2_0037',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0037.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Teacher, I don't know the answer.",
#                'tag': 'student_6_question_2_0012',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0012.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0038',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0038.wav?download=true',
#                  'responses': []}]}]}]}]}]}]}]},
#   {'speaker': 'student_3',
#    'message': "I believe it's a quadratic function.",
#    'tag': 'student_3_question_2_0013',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0013.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'You are correct that it is described by a quadratic function. Think of the specific geometric shape that results from graphing a quadratic equation.',
#      'tag': 'teacher_1_question_2_0039',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0039.wav?download=true',
#      'responses': [{'speaker': 'student_2',
#        'message': 'Okay, so for a quadratic function... is it a parabola? That U-shaped graph?',
#        'tag': 'student_2_question_2_0014',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0014.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Correct. A projectile's path follows a parabola.",
#          'tag': 'teacher_1_question_2_0040',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0040.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Oh, so that's why the path is always curved like that when something flies through the air.",
#            'tag': 'student_2_question_2_0015',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0015.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0041',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0041.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Oh, so like the arch shape. That makes sense.',
#                'tag': 'student_2_question_2_0016',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0016.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good description of the shape! The mathematical function that a path of a projectile follows is a parabola.",
#                  'tag': 'teacher_1_question_2_0042',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0042.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'That makes perfect sense, thinking about the arc. I can really visualize that.',
#                'tag': 'student_3_question_2_0014',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0014.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0043',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0043.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know the answer.",
#                'tag': 'student_6_question_2_0013',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0013.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'The mathematical function that a path of a projectile follows is a parabola. This occurs because the constant force of gravity acts vertically on the projectile, causing it to trace this specific symmetrical curved path.',
#                  'tag': 'teacher_1_question_2_0044',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0044.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "That makes sense. I can really see how the math behind the parabola applies to something like a ball being thrown. It's fascinating how those concepts connect.",
#            'tag': 'student_3_question_2_0015',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0015.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct! The path of a projectile follows a parabola.",
#              'tag': 'teacher_1_question_2_0045',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0045.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Uh... I don't know.",
#            'tag': 'student_6_question_2_0014',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0014.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0046',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0046.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Oh, so it makes a curved path, like a parabola.',
#                'tag': 'student_2_question_2_0017',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0017.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct.',
#                  'tag': 'teacher_1_question_2_0047',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0047.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, so the path is a parabola. I've got that down.",
#                'tag': 'student_3_question_2_0016',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0016.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0048',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0048.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Okay.',
#                'tag': 'student_6_question_2_0015',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0015.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'What mathematical function does a path of a projectile follow?',
#                  'tag': 'teacher_1_question_2_0049',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0049.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Oh, I know! It's a parabola.",
#        'tag': 'student_3_question_2_0017',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0017.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Correct!',
#          'tag': 'teacher_1_question_2_0050',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0050.wav?download=true',
#          'responses': []}]},
#       {'speaker': 'student_6',
#        'message': "Um... I don't know.",
#        'tag': 'student_6_question_2_0016',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0016.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Remember that the path of a projectile, like a ball thrown in the air, follows a specific curve. Think of the name of that common mathematical curve.',
#          'tag': 'teacher_1_question_2_0051',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0051.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Oh, isn't it called a parabola?",
#            'tag': 'student_2_question_2_0018',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0018.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Correct.',
#              'tag': 'teacher_1_question_2_0052',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0052.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Right.',
#                'tag': 'student_2_question_2_0019',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0019.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'That is not the answer I am looking for. Think of the specific curve shape that describes the path of a projectile under gravity.',
#                  'tag': 'teacher_1_question_2_0053',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0053.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Understood. Thank you. It's good to see I'm on the right track.",
#                'tag': 'student_3_question_2_0018',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0018.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Let us continue.\n\nWhat mathematical function does a path of a projectile follow?',
#                  'tag': 'teacher_1_question_2_0054',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0054.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I... I don't know.",
#                'tag': 'student_6_question_2_0017',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0017.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The path of a projectile follows a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0055',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0055.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "It's a parabola!",
#            'tag': 'student_3_question_2_0019',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0019.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "Correct! That's precisely right.",
#              'tag': 'teacher_1_question_2_0056',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0056.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Umm, I don't know.",
#            'tag': 'student_6_question_2_0018',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0018.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that the path of a projectile is a symmetrical curve, often seen in graphs of quadratic equations.',
#              'tag': 'teacher_1_question_2_0057',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0057.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, so like a curve... a really balanced curve, right?',
#                'tag': 'student_2_question_2_0020',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0020.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'The path of a projectile follows a parabola.',
#                  'tag': 'teacher_1_question_2_0058',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0058.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Yes, I remember that. The symmetry of the projectile's path really highlights how quadratic equations model real-world motion, which is quite interesting.",
#                'tag': 'student_3_question_2_0020',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0020.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The correct mathematical function describing the path of a projectile is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0059',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0059.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh... it's a symmetrical curve, like from quadratic graphs.",
#                'tag': 'student_6_question_2_0019',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0019.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'You are on the right track by mentioning a symmetrical curve and quadratic graphs. However, what is the specific mathematical term for that symmetrical curve formed by a quadratic function?\n\nRemember that the graph of a quadratic function creates a unique U-shaped curve.',
#                  'tag': 'teacher_1_question_2_0060',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0060.wav?download=true',
#                  'responses': []}]}]}]}]}]}]}]},
#   {'speaker': 'student_6',
#    'message': "I just... I don't know that one.",
#    'tag': 'student_6_question_2_0020',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0020.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': "That's alright. Think of the shape that a ball makes when you throw it up in the air. What mathematical function does that path follow?",
#      'tag': 'teacher_1_question_2_0061',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0061.wav?download=true',
#      'responses': [{'speaker': 'student_2',
#        'message': "Oh, like the shape it makes? That's a parabola, right? So it would be a quadratic function.",
#        'tag': 'student_2_question_2_0021',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0021.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Correct. A projectile's path follows a parabolic trajectory, which is described by a quadratic function. That's all for that question.",
#          'tag': 'teacher_1_question_2_0062',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0062.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Okay, that makes sense! I'm ready for the next one.",
#            'tag': 'student_2_question_2_0022',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0022.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0063',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0063.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, got it.',
#                'tag': 'student_2_question_2_0023',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0023.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'What mathematical function does a path of a projectile follow?',
#                  'tag': 'teacher_1_question_2_0064',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0064.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'That makes a lot of sense. So, like a ball thrown in the air, its path is always that shape.',
#                'tag': 'student_3_question_2_0021',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0021.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct. The mathematical function for a projectile's path is a parabola.",
#                  'tag': 'teacher_1_question_2_0065',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0065.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Uh huh.',
#                'tag': 'student_6_question_2_0021',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0021.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0066',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0066.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Okay, I understand. I'm ready for the next question.",
#            'tag': 'student_3_question_2_0022',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0022.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'We are discussing the path of a projectile. What mathematical function does a path of a projectile follow?',
#              'tag': 'teacher_1_question_2_0067',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0067.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, okay. So when something flies through the air... it makes a curve shape, right? I think that's called a parabola in math.",
#                'tag': 'student_2_question_2_0024',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0024.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's called a parabola in math.",
#                  'tag': 'teacher_1_question_2_0068',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0068.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "The path of a projectile follows a parabolic function. It's really interesting how that shape comes from constant acceleration downwards.",
#                'tag': 'student_3_question_2_0023',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0023.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct. The path of a projectile follows a parabolic function.',
#                  'tag': 'teacher_1_question_2_0069',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0069.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know, Teacher.",
#                'tag': 'student_6_question_2_0022',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0022.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0070',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0070.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': 'Mhm.',
#            'tag': 'student_6_question_2_0023',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0023.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Think of the specific curved shape that objects follow when they are thrown upwards and then fall back down due to gravity.',
#              'tag': 'teacher_1_question_2_0071',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0071.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Oh, like when you throw a ball? It makes kind of an arc shape, right? Like a curved path.',
#                'tag': 'student_2_question_2_0025',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0025.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good description of the path, you're right that it's an arc shape and a curved path. However, the specific mathematical function that a path of a projectile follows is a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0072',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0072.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, that's an interesting one. I'm thinking about it, and the shape they make is a parabola. It's like a perfect curve, isn't it?",
#                'tag': 'student_3_question_2_0024',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0024.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct. The path of a projectile follows a parabola.',
#                  'tag': 'teacher_1_question_2_0073',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0073.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_2_0024',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0024.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0074',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0074.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': 'A parabola. That path follows a quadratic function.',
#        'tag': 'student_3_question_2_0025',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0025.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "That's correct!",
#          'tag': 'teacher_1_question_2_0075',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0075.wav?download=true',
#          'responses': []}]},
#       {'speaker': 'student_6',
#        'message': 'Uh, a parabola? So, like, a quadratic function?',
#        'tag': 'student_6_question_2_0025',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0025.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Correct. That's all for that question.",
#          'tag': 'teacher_1_question_2_0076',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0076.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Alright, sounds good. What's next for us?",
#            'tag': 'student_2_question_2_0026',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0026.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0077',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0077.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'So, like a big arc, every time?',
#                'tag': 'student_2_question_2_0027',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0027.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The path of a projectile follows a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0078',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0078.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "That's a clear connection between math and physics.",
#                'tag': 'student_3_question_2_0026',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0026.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Thank you for sharing your thoughts on the connection, but that is not the specific mathematical function I am looking for. The path of a projectile follows a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0079',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0079.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_2_0026',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0026.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Think of the common shape that a thrown object makes as it flies through the air, like a ball thrown upwards. What mathematical curve does that path resemble?',
#                  'tag': 'teacher_1_question_2_0080',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0080.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': 'Okay.',
#            'tag': 'student_3_question_2_0027',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0027.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'What mathematical function does the path of a projectile follow?',
#              'tag': 'teacher_1_question_2_0081',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0081.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, isn't that a parabola?",
#                'tag': 'student_2_question_2_0028',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0028.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_2_0082',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0082.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "The path of a projectile follows a parabolic function. It's really interesting how that shape relates to quadratic equations in math.",
#                'tag': 'student_3_question_2_0028',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0028.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Excellent work!',
#                  'tag': 'teacher_1_question_2_0083',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0083.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know, teacher. I just can't think of it right now.",
#                'tag': 'student_6_question_2_0027',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0027.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'The mathematical function that a path of a projectile follows is a parabola.',
#                  'tag': 'teacher_1_question_2_0084',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0084.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': 'Mhm.',
#            'tag': 'student_6_question_2_0028',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0028.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.",
#              'tag': 'teacher_1_question_2_0085',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0085.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Okay, so it's a parabola. Got it.",
#                'tag': 'student_2_question_2_0029',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0029.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0086',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0086.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, that's really interesting. So it's always a curve like that when something is thrown or shot.",
#                'tag': 'student_3_question_2_0029',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0029.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "While it is indeed a curve, can you recall the specific mathematical function that describes the path of a projectile? The path of a projectile follows a parabola. That's all for that question.",
#                  'tag': 'teacher_1_question_2_0087',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0087.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Ugh. I don't know.",
#                'tag': 'student_6_question_2_0029',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0029.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "The mathematical function that a path of a projectile follows is a parabola. That's it for that item.",
#                  'tag': 'teacher_1_question_2_0088',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0088.wav?download=true',
#                  'responses': []}]}]}]}]}]}]}]}]}

# %%
def find_speaker_responses(data, speaker_name):
    """
    Find the first node that matches the speaker_name by traversing children recursively.
    
    Args:
        data: The JSON data structure (can be a dict or list)
        speaker_name: The speaker name to search for
        
    Returns:
        The first matching node or None if not found
    """
    if isinstance(data, dict):
        # get the responses of this node
        if 'responses' in data:
            data = data['responses']    
    if isinstance(data, list):        # Search through list items
        nodes = []
        for item in data:
            if 'responses' in item:
                for child in item['responses']:
                    if child.get('speaker') == speaker_name:
                        nodes.append(child)
        return nodes
    
    return None

start_node = get_question("teacher_1",0)
print(start_node)

next_nodes_1 = find_speaker_responses(start_node['responses'], "teacher_1")
print("next_nodes(1) length: ", len(next_nodes_1))
for node in next_nodes_1:
    print(">>>", node['message'])
# Out:
# teacher_1
# {'message': "Good morning! Let's explore this together. In the context of projectile motion, how would you define a projectile?", 'question': 'Within the topic of projectile motion, how would you describe a projectile?', 'criteria': '', 'audio': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0001.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.", 'tag': 'student_2_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', 'tag': 'teacher_1_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0002.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's mainly about gravity then, for the ideal one.", 'tag': 'student_2_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'tag': 'teacher_1_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.", 'tag': 'student_2_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.', 'tag': 'student_3_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.', 'tag': 'teacher_1_question_1_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.', 'tag': 'student_2_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true ...
# next_nodes(1) length:  3
# >>> You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.
# >>> That's correct!
# >>> Within the topic of projectile motion, how would you describe a projectile?
#
# Think of how you would make something fly through the air.

# %%
#Get the second level
next_parent_2 = next_nodes_1[0]
print('next_parent(2)', next_parent_2['message'])
next_nodes_2 = find_speaker_responses(next_parent_2['responses'], "teacher_1")
print("next_nodes(2) length: ", len(next_nodes_2))
for node in next_nodes_2:
    print(">>>", node['message'])
# Out:
# next_parent(2) You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.
# next_nodes(2) length:  3
# >>> You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?
# >>> Within the topic of projectile motion, how would you describe a projectile?
# >>> Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air.

# %%
#Get the second level
next_parent_2 = next_nodes_1[0]
print('next_parent(2)', next_parent_2['message'])
next_nodes_2 = find_speaker_responses(next_parent_2, "teacher_1")
print("next_nodes(2) length: ", len(next_nodes_2))
for node in next_nodes_2:
    print(">>>", node['message'])
# Out:
# next_parent(2) Exactly! And what's special about these two components?
# next_nodes(2) length:  2
# >>> Perfect! That's the key insight of projectile motion.
# >>> Brilliant observation! Yes, horizontal velocity stays constant while vertical motion accelerates due to gravity.

# %%
#Get the third level
next_parent_3 = next_nodes_2[0]
print('next_parent(3)', next_parent_3['message'])

if 'responses' in next_parent_3:  
    next_nodes_3 = find_speaker_responses(next_parent_3['responses'], "teacher_1")
    print("next_nodes(3) length: ", len(next_nodes_3))
    for node in next_nodes_3:
        print(">>>", node['message'])
else:
    print("No responses found for next_parent_3")
    # Let's move
# Out:
# next_parent(3) You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?
# next_nodes(3) length:  3
# >>> That's correct!
# >>> That's correct!
# >>> Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.

# %%
# check the next question
start_node = get_question("teacher_1",1)
print(start_node)

next_nodes_1 = find_speaker_responses(start_node['responses'], "teacher_1")
print("next_nodes(1) length: ", len(next_nodes_1))
for node in next_nodes_1:
    print(">>>", node['message'])
# Out:
# teacher_1
# {'message': "Hi there! I'd like you to think about something. What mathematical function describes the path of a projectile?", 'question': 'What mathematical function does a path of a projectile follow?', 'criteria': '', 'audio': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0001.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Oh, is it a quadratic function?', 'tag': 'student_2_question_2_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'You are very close! A quadratic function does describe the path. Now, think of the specific geometric shape that the graph of a quadratic function creates. What is that shape called?', 'tag': 'teacher_1_question_2_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0002.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Oh, I remember that! It's called a parabola, right?", 'tag': 'student_2_question_2_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Correct.', 'tag': 'teacher_1_question_2_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay, cool!', 'tag': 'student_2_question_2_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'What mathematical function does a path of a projectile follow?', 'tag': 'teacher_1_question_2_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0004.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Oh, it's that curve shape, like a parabola. So, it's a quadratic function, right?", 'tag': 'student_2_question_2_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_2_0004.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct! The path of a projectile follows a parabola, which is represented by a quadratic function.", 'tag': 'teacher_1_question_2_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'It follows a quadratic function!', 'tag': 'student_3_question_2_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Excellent work! The path of a projectile indeed follows a quadratic function.', 'tag': 'teacher_1_question_2_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0006.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_2_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_2_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "The mathematical function that a path of a projectile follows is a parabola. That's all for that question.", 'tag': 'teacher_1_question_2_0007', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_2_0007.wav?download=true', 'responses': []}]}]}]}, {'speaker': 'student_3', 'message': 'Excellent. That really solidifies my understanding.', 'tag': 'student_3_question_2_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_2_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'The math ...
# next_nodes(1) length:  3
# >>> You are very close! A quadratic function does describe the path. Now, think of the specific geometric shape that the graph of a quadratic function creates. What is that shape called?
# >>> You are correct that it is described by a quadratic function. Think of the specific geometric shape that results from graphing a quadratic equation.
# >>> That's alright. Think of the shape that a ball makes when you throw it up in the air. What mathematical function does that path follow?

# %%
#Get the second level
next_parent_2 = next_nodes_1[0]
print('next_parent(2)', next_parent_2['message'])
next_nodes_2 = find_speaker_responses(next_parent_2['responses'], "teacher_1")
print("next_nodes(2) length: ", len(next_nodes_2))
for node in next_nodes_2:
    print(">>>", node['message'])
# Out:
# next_parent(2) You are very close! A quadratic function does describe the path. Now, think of the specific geometric shape that the graph of a quadratic function creates. What is that shape called?
# next_nodes(2) length:  3
# >>> Correct.
# >>> Correct.
# >>> Remember that the shape of the path of any object thrown or launched into the air, subject only to gravity, has a specific mathematical curve. What is that curve called?

# %%
question_index = 0
current_node = None
def build_response_prompt(speaker_name):

    """
    Return prompt to choose the best response from the node.
    """
    global current_node
    global question_index

    question_node = get_question(speaker_name, question_index)

    if current_node is None:
        current_node = get_question(speaker_name, question_index)


    response_nodes = find_speaker_responses(current_node['responses'], speaker_name)
    response_messages = []
    tags = []
    for node in response_nodes:
        response_messages.append(node['message'])
        tags.append(node['tag'])

    # build the prompt

    question_or_message = current_node.get("question") or current_node.get("message")

    prompt = f""" You are a tutor assessing a student's response. Choose the best response from the list of responses based on the criteria. Respond verbatim from the response.
    Question: {question_or_message}
    Criteria: {question_node['criteria']}
    Responses: {response_messages}
    """
    return (prompt, response_messages, tags)

response_prompt, response_messages, tags = build_response_prompt('teacher_1')
print(response_prompt)
print(response_messages)
print(tags)
# Out:
# teacher_1
# teacher_1
#  You are a tutor assessing a student's response. Choose the best response from the list of responses based on the criteria. Respond verbatim from the response.
#     Question: Within the topic of projectile motion, how would you describe a projectile?
#     Criteria:
#     Responses: ['You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', "That's correct!", 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of how you would make something fly through the air.']
#
# ['You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', "That's correct!", 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of how you would make something fly through the air.']
# ['teacher_1_question_1_0002', 'teacher_1_question_1_0033', 'teacher_1_question_1_0034']

# %%
current_node
# Out:
# {'message': "Good morning! Let's explore this together. In the context of projectile motion, how would you define a projectile?",
#  'question': 'Within the topic of projectile motion, how would you describe a projectile?',
#  'criteria': '',
#  'audio': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0001.wav?download=true',
#  'responses': [{'speaker': 'student_2',
#    'message': "Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.",
#    'tag': 'student_2_question_1_0001',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0001.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.',
#      'tag': 'teacher_1_question_1_0002',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0002.wav?download=true',
#      'responses': [{'speaker': 'student_2',
#        'message': "Okay, so it's mainly about gravity then, for the ideal one.",
#        'tag': 'student_2_question_1_0002',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?",
#          'tag': 'teacher_1_question_1_0003',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.",
#            'tag': 'student_2_question_1_0003',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0004',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_3',
#            'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.',
#            'tag': 'student_3_question_1_0001',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0005',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "I don't know.",
#            'tag': 'student_6_question_1_0001',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.',
#              'tag': 'teacher_1_question_1_0006',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.',
#                'tag': 'student_2_question_1_0004',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0007',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0007.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is any object that's thrown or launched into the air. Once it's moving, the primary force that pulls it back down is gravity.",
#                'tag': 'student_3_question_1_0002',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0002.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0008',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0008.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0002',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0002.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of an object that is launched or thrown, and remember that its path through the air is mainly determined by a specific natural force. Now, how would you describe a projectile?',
#                  'tag': 'teacher_1_question_1_0009',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0009.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Yes, I see, Teacher. So, for the ideal definition, the focus is just on gravity, and other forces like air resistance aren't considered. That makes a lot of sense for simplifying the concept. I'm ready.",
#        'tag': 'student_3_question_1_0003',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0003.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Within the topic of projectile motion, how would you describe a projectile?',
#          'tag': 'teacher_1_question_1_0010',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0010.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'A projectile is like anything that gets launched or thrown into the air.',
#            'tag': 'student_2_question_1_0005',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0005.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've mentioned that a projectile is an object launched or thrown into the air, which is a good start. However, your definition is not yet complete. Think of the primary force that acts on the object once it is in the air.",
#              'tag': 'teacher_1_question_1_0011',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0011.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, okay! So it's about the force that pulls it down, right? Like gravity?",
#                'tag': 'student_2_question_1_0006',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0006.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are correct that gravity is a crucial part of it. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0012',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0012.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So, a projectile is an object launched or thrown into the air, and once it's in the air, the only significant force acting on it is gravity.",
#                'tag': 'student_3_question_1_0004',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0004.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0013',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0013.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0003',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0003.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Within the topic of projectile motion, how would you describe a projectile? You mentioned you don't know.\n\nThink of an object that is launched into the air, and consider the primary force that acts upon it once it's in flight.",
#                  'tag': 'teacher_1_question_1_0014',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0014.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "A projectile is an object that's launched or thrown into the air, and then the only force acting on it is gravity. We typically ignore air resistance in this context. It's really interesting how it follows that curved path!",
#            'tag': 'student_3_question_1_0005',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0005.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0015',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0015.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Uh, I don't know.",
#            'tag': 'student_6_question_1_0004',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0004.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that a projectile is an object that is set in motion and then moves only under a specific natural force. Now, how would you describe a projectile?',
#              'tag': 'teacher_1_question_1_0016',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0016.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it's like when you throw something, or like a ball you kick, and then gravity just takes it over?",
#                'tag': 'student_2_question_1_0007',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0007.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good Job! That's it for that item.",
#                  'tag': 'teacher_1_question_1_0017',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0017.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, so a projectile is an object that's set in motion and then, once it's moving, the only natural force acting on it is gravity.",
#                'tag': 'student_3_question_1_0006',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0006.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good attempt, but let's refine it to be more precise. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0018',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0018.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'I dunno',
#                'tag': 'student_6_question_1_0005',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0005.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0019',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0019.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_6',
#        'message': "Uh... I don't know.",
#        'tag': 'student_6_question_1_0006',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0006.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air.",
#          'tag': 'teacher_1_question_1_0020',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0020.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': "It's gravity, right? That's the main one pulling things down.",
#            'tag': 'student_2_question_1_0008',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0008.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Your answer correctly identifies gravity as a key factor. However, the definition of a projectile also involves how the object is initially set into motion. Think of how a projectile begins its movement. How is it typically put into the air?',
#              'tag': 'teacher_1_question_1_0021',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0021.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh right. It's usually thrown or launched into the air.",
#                'tag': 'student_2_question_1_0009',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0009.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0022',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0022.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So, a projectile is also something that's given an initial push or throw, or launched into the air. Like, it's not just sitting there, it starts with a force.",
#                'tag': 'student_3_question_1_0007',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0007.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's a good start, but to be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0023',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0023.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I'm not sure.",
#                'tag': 'student_6_question_1_0007',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0007.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0024',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0024.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Okay, I understand. Once a projectile is in the air, the primary force acting on it is gravity. It's always pulling it downwards, which makes sense because everything eventually falls.",
#            'tag': 'student_3_question_1_0008',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0008.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've correctly identified that gravity is a primary force acting on a projectile once it's in the air. However, to fully describe a projectile, consider what kind of object it is and how it initially gets into motion.\n\nTry to imagine what kind of object we are discussing and how it begins its movement into the air.",
#              'tag': 'teacher_1_question_1_0025',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0025.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it's like, anything that gets thrown or launched? Like a baseball? And it starts moving because something pushes it really hard, like when you throw it.",
#                'tag': 'student_2_question_1_0010',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0010.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are close! You correctly identified that it's anything that gets thrown or launched. However, a projectile is more precisely defined as any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0026',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0026.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is an object that's launched or thrown into the air, and it gets its initial motion from that push or force that sends it off.",
#                'tag': 'student_3_question_1_0009',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0009.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You're very close! You correctly identified that a projectile is an object launched or thrown. However, a key part of the definition is what continues to influence its motion once it's in the air.\n\nA projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.",
#                  'tag': 'teacher_1_question_1_0027',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0027.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I... I don't really know.",
#                'tag': 'student_6_question_1_0008',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0008.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0028',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0028.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "I don't know.",
#            'tag': 'student_6_question_1_0009',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0009.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Try to imagine an object that has been launched into the air, and consider the primary force that acts upon it during its flight.',
#              'tag': 'teacher_1_question_1_0029',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0029.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Hmm okay, an object launched into the air. So it goes up, and then it comes back down, right? I guess the main force acting on it would be gravity.',
#                'tag': 'student_2_question_1_0011',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0011.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0030',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0030.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, that's an interesting thought experiment! The primary force acting on it would definitely be gravity.",
#                'tag': 'student_3_question_1_0010',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0010.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0031',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0031.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uhm, I don't know.",
#                'tag': 'student_6_question_1_0010',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0010.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Remember that a projectile is an object initially set into motion and then moves predominantly under a single natural force.',
#                  'tag': 'teacher_1_question_1_0032',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0032.wav?download=true',
#                  'responses': []}]}]}]}]}]}]}]},
#   {'speaker': 'student_3',
#    'message': "Good morning, teacher! I've really been focusing on this topic. From my understanding, a projectile is any object that's launched or thrown into the air, and then, once it's moving, the only important force acting on it is gravity.",
#    'tag': 'student_3_question_1_0011',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0011.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': "That's correct!",
#      'tag': 'teacher_1_question_1_0033',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0033.wav?download=true',
#      'responses': []}]},
#   {'speaker': 'student_6',
#    'message': "Um, I don't know.",
#    'tag': 'student_6_question_1_0011',
#    'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0011.wav?download=true',
#    'responses': [{'speaker': 'teacher_1',
#      'message': 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink of how you would make something fly through the air.',
#      'tag': 'teacher_1_question_1_0034',
#      'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0034.wav?download=true',
#      'responses': [{'speaker': 'student_2',
#        'message': "Oh, a projectile? It's basically anything that gets thrown or launched into the air, and then it just keeps going.",
#        'tag': 'student_2_question_1_0012',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0012.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Your description is close, but it is incomplete. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#          'tag': 'teacher_1_question_1_0035',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0035.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Okay, I get it. So, gravity is the main thing that keeps it going.',
#            'tag': 'student_2_question_1_0013',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0013.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You've correctly identified that gravity is a key factor. However, the definition of a projectile also describes how it begins its motion.\n\nRemember that a projectile needs an initial push or throw to start its journey. Please try to describe a projectile again, keeping both its initial motion and the influence of gravity in mind.",
#              'tag': 'teacher_1_question_1_0036',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0036.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, so a projectile is like something you throw or kick, and then gravity pulls it down as it flies through the air.',
#                'tag': 'student_2_question_1_0014',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0014.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good job. That's a very good description of a projectile.",
#                  'tag': 'teacher_1_question_1_0037',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0037.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': 'Okay, so a projectile is an object that gets an initial push or throw, and then the only thing affecting its movement is gravity.',
#                'tag': 'student_3_question_1_0012',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0012.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Good job. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0038',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0038.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh, it's something that gets like, an initial push or throw, and then only gravity affects it.",
#                'tag': 'student_6_question_1_0012',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0012.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "Correct. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0039',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0039.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': "Okay, so it's any object set in motion through the air, and then only gravity acts on it. Got it! That makes it clearer.",
#            'tag': 'student_3_question_1_0013',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0013.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0040',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0040.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': 'Right.',
#            'tag': 'student_6_question_1_0013',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0013.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#              'tag': 'teacher_1_question_1_0041',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0041.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': 'Okay, makes sense.',
#                'tag': 'student_2_question_1_0015',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0015.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0042',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0042.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, I understand. So it's just about gravity once it's in the air. Got it.",
#                'tag': 'student_3_question_1_0014',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0014.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.',
#                  'tag': 'teacher_1_question_1_0043',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0043.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Uh-huh.',
#                'tag': 'student_6_question_1_0014',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0014.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0044',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0044.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_3',
#        'message': "Okay, so a projectile... thinking about how something flies through the air, it's basically any object that's been thrown, shot, or launched into space. And then, once it's moving, the only main force affecting its path is gravity, you know, pulling it downwards. That's how I'd describe it.",
#        'tag': 'student_3_question_1_0015',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0015.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': 'Your description is mostly accurate, highlighting the object being set in motion and gravity as the sole influence. However, consider the specific medium in which typical projectile motion occurs.\n\nThink of the environment where a projectile moves when we study it in physics.',
#          'tag': 'teacher_1_question_1_0045',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0045.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Hmm, so like, the air around it?',
#            'tag': 'student_2_question_1_0016',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0016.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Remember that a projectile is an object that is set into motion. Think of the specific force that acts upon this object once it is moving through the air, completely independent of its initial push.',
#              'tag': 'teacher_1_question_1_0046',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0046.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Hmm, so after it's been pushed, the force that's always there... is it gravity?",
#                'tag': 'student_2_question_1_0017',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0017.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "You are correct that gravity is the force involved. A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0047',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0047.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "That would be the force of gravity. It's the continuous downward pull on the object, completely independent of its initial push.",
#                'tag': 'student_3_question_1_0016',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0016.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0048',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0048.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'I dunno.',
#                'tag': 'student_6_question_1_0015',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0015.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0049',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0049.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_3',
#            'message': 'Oh, I see what you mean! When we talk about typical projectile motion, the object is usually moving through the air. So, air resistance would also be a factor, even if we sometimes simplify problems by neglecting it.',
#            'tag': 'student_3_question_1_0017',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0017.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Your understanding of air resistance as a factor in real-world scenarios is correct. However, for the definition of an ideal projectile in physics, we often simplify the forces involved.\n\nThink about the action that starts an object on a projectile path and the fundamental natural force that continuously acts upon it as it travels through the air.',
#              'tag': 'teacher_1_question_1_0050',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0050.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Okay, so for an ideal projectile, it starts with like, an initial push or launch, right? And then it's just gravity pulling it down the whole time?",
#                'tag': 'student_2_question_1_0018',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0018.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'Correct. That is a good description of a projectile.',
#                  'tag': 'teacher_1_question_1_0051',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0051.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Oh, I see! So for an ideal projectile, we're simplifying things. The action that starts it is its initial velocity, and the only continuous force acting on it would be gravity.",
#                'tag': 'student_3_question_1_0018',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0018.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! Good job.",
#                  'tag': 'teacher_1_question_1_0052',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0052.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': 'Um... just gravity, I guess?',
#                'tag': 'student_6_question_1_0016',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0016.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's it for that item.",
#                  'tag': 'teacher_1_question_1_0053',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0053.wav?download=true',
#                  'responses': []}]}]}]},
#           {'speaker': 'student_6',
#            'message': "Um... it's usually in the air, right? But sometimes we just ignore the air part for the problems.",
#            'tag': 'student_6_question_1_0017',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0017.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "You are close, but let's refine that definition. Think of how the object begins its journey and what primary force acts upon it once it's moving through the air.",
#              'tag': 'teacher_1_question_1_0054',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0054.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Oh, so it starts off with like, an initial push, right? And then gravity is the main thing pulling it down while it's in the air?",
#                'tag': 'student_2_question_1_0019',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0019.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! You've accurately described a projectile.",
#                  'tag': 'teacher_1_question_1_0055',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0055.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "Okay, I think I see what you mean. So, it starts when something is launched or thrown, and then the main force acting on it while it's in the air is gravity, pulling it downwards.",
#                'tag': 'student_3_question_1_0019',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0019.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! A projectile is indeed an object that is launched or thrown, and its motion through the air is primarily influenced by gravity.",
#                  'tag': 'teacher_1_question_1_0056',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0056.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "Uh... I guess it's when something gets, like, thrown, and then gravity just pulls it down while it's in the air?",
#                'tag': 'student_6_question_1_0018',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0018.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct!",
#                  'tag': 'teacher_1_question_1_0057',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0057.wav?download=true',
#                  'responses': []}]}]}]}]}]},
#       {'speaker': 'student_6',
#        'message': "I don't know.",
#        'tag': 'student_6_question_1_0019',
#        'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0019.wav?download=true',
#        'responses': [{'speaker': 'teacher_1',
#          'message': "Think of an object that is set in motion through the air, and what the only significant force acting upon it is once it's moving freely. What would you call such an object?",
#          'tag': 'teacher_1_question_1_0058',
#          'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0058.wav?download=true',
#          'responses': [{'speaker': 'student_2',
#            'message': 'Hmm, like a baseball thrown in the air? I guess gravity would be the main force pulling it down. And... what do you call it? Is it a projectile?',
#            'tag': 'student_2_question_1_0020',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0020.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct! A projectile is indeed any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.",
#              'tag': 'teacher_1_question_1_0059',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0059.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_3',
#            'message': "Oh, I've got this! So, if an object is set in motion through the air, like a basketball shot, the only significant force acting on it once it's freely moving is gravity. We would call that object a projectile.",
#            'tag': 'student_3_question_1_0020',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0020.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': "That's correct!",
#              'tag': 'teacher_1_question_1_0060',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0060.wav?download=true',
#              'responses': []}]},
#           {'speaker': 'student_6',
#            'message': "Uh, I don't know.",
#            'tag': 'student_6_question_1_0020',
#            'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0020.wav?download=true',
#            'responses': [{'speaker': 'teacher_1',
#              'message': 'Within the topic of projectile motion, how would you describe a projectile?',
#              'tag': 'teacher_1_question_1_0061',
#              'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0061.wav?download=true',
#              'responses': [{'speaker': 'student_2',
#                'message': "Hmm, a projectile? I guess it's basically anything that gets thrown or launched into the air.",
#                'tag': 'student_2_question_1_0021',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0021.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': 'You are correct that a projectile is anything that gets thrown or launched into the air. To be precise, a projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone.',
#                  'tag': 'teacher_1_question_1_0062',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0062.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_3',
#                'message': "A projectile is essentially any object that's launched or thrown, and then its only significant force acting on it is gravity. We usually simplify it by not considering air resistance in our initial studies.",
#                'tag': 'student_3_question_1_0021',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0021.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "That's correct! You have accurately described a projectile.",
#                  'tag': 'teacher_1_question_1_0063',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0063.wav?download=true',
#                  'responses': []}]},
#               {'speaker': 'student_6',
#                'message': "I don't know.",
#                'tag': 'student_6_question_1_0021',
#                'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0021.wav?download=true',
#                'responses': [{'speaker': 'teacher_1',
#                  'message': "A projectile is any object that is thrown, launched, or otherwise set in motion through the air and continues to move under the influence of gravity alone. That's all for that question.",
#                  'tag': 'teacher_1_question_1_0064',
#                  'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0064.wav?download=true',
#                  'responses': []}]}]}]}]}]}]}]}]}

# %%
next_node = current_node['responses'][0]['responses'][0]
print(next_node)
# Out:
# {'speaker': 'teacher_1', 'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', 'tag': 'teacher_1_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0002.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's mainly about gravity then, for the ideal one.", 'tag': 'student_2_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'tag': 'teacher_1_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.", 'tag': 'student_2_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.', 'tag': 'student_3_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.', 'tag': 'teacher_1_question_1_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.', 'tag': 'student_2_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0007', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0007.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': "A projectile is any object that's thrown or launched into the air. Once it's moving, the primary force that pulls it back down is gravity.", 'tag': 'student_3_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0008', 'audio link': 'https://huggingfac ...

# %%
current_node = next_node

response_prompt, response_messages, tags = build_response_prompt('teacher_1')
print(response_prompt)
print(response_messages)  
print(tags)
# Out:
# teacher_1
#  You are a tutor assessing a student's response. Choose the best response from the list of responses based on the criteria. Respond verbatim from the response.
#     Question: You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.
#     Criteria:
#     Responses: ["You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'Within the topic of projectile motion, how would you describe a projectile?', "Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air."]
#
# ["You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'Within the topic of projectile motion, how would you describe a projectile?', "Remember that a projectile is an object that is set into motion, and consider the primary force that acts on it once it's in the air."]
# ['teacher_1_question_1_0003', 'teacher_1_question_1_0010', 'teacher_1_question_1_0020']

# %%
def find_node_by_tag(tag):
    """
    Find the node with the given tag from the JSON data.
    
    Args:
        tag (str): The tag to search for
        
    Returns:
        dict: The node with the matching tag, or None if not found
    """
    def search_recursive(data):
        """Recursively search through the data structure for the tag."""
        if isinstance(data, dict):
            if data.get('tag') == tag:
                return data
            # Search in responses if they exist
            if 'responses' in data:
                for response in data['responses']:
                    result = search_recursive(response)
                    if result:
                        return result
            # Search in children if they exist
            if 'children' in data:
                for child in data['children']:
                    result = search_recursive(child)
                    if result:
                        return result
        elif isinstance(data, list):
            for item in data:
                result = search_recursive(item)
                if result:
                    return result
        return None
    
    # Start the search from the questions
    if 'questions' in JSON_DATA:
        for question in JSON_DATA['questions']:
            result = search_recursive(question)
            if result:
                return result
    
    return None

node = find_node_by_tag('teacher_1_question_1_0001')
print(node)
# Out:
# {'speaker': 'teacher_1', 'message': "Good morning! Let's explore this together. In the context of projectile motion, how would you define a projectile?", 'tag': 'teacher_1_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0001.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.", 'tag': 'student_2_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', 'tag': 'teacher_1_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0002.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's mainly about gravity then, for the ideal one.", 'tag': 'student_2_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'tag': 'teacher_1_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.", 'tag': 'student_2_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.', 'tag': 'student_3_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.', 'tag': 'teacher_1_question_1_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.', 'tag': 'student_2_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true', 'responses': [{'speaker': 'teacher_1',  ...

# %%
node = find_node_by_tag('student_2_question_1_0002')
print(node)
# Out:
# {'speaker': 'student_2', 'message': "Okay, so it's mainly about gravity then, for the ideal one.", 'tag': 'student_2_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'tag': 'teacher_1_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.", 'tag': 'student_2_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.', 'tag': 'student_3_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.', 'tag': 'teacher_1_question_1_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.', 'tag': 'student_2_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0007', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0007.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': "A projectile is any object that's thrown or launched into the air. Once it's moving, the primary force that pulls it back down is gravity.", 'tag': 'student_3_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0008', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0008.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile?\n\nThink o ...

# %%
node = find_node_by_tag('student_2_question_1_0001')
print(node)
# Out:
# {'speaker': 'student_2', 'message': "Okay, so a projectile is pretty much an object that's thrown or launched into the air, and then it just keeps moving, mostly because of gravity.", 'tag': 'student_2_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'You are correct that a projectile is an object that is thrown or launched into the air and that gravity affects its motion. Remember that in the ideal definition of projectile motion, all other forces apart from gravity are typically disregarded.', 'tag': 'teacher_1_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0002.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's mainly about gravity then, for the ideal one.", 'tag': 'student_2_question_1_0002', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0002.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "You are correct that gravity is a key factor. Now, remember that a projectile isn't just standing still. Think of how a projectile is initially set in motion. How would you describe a projectile, considering both its initial motion and the force acting on it?", 'tag': 'teacher_1_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0003.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': "Okay, so it's like anything that gets launched or thrown, and then gravity is the main force pulling it down.", 'tag': 'student_2_question_1_0003', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0003.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0004.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': 'A projectile is an object that is launched or thrown with an initial velocity, and then the only significant force acting on it is gravity.', 'tag': 'student_3_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_3_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0005', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0005.wav?download=true', 'responses': []}]}, {'speaker': 'student_6', 'message': "I don't know.", 'tag': 'student_6_question_1_0001', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_6_question_1_0001.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': 'Within the topic of projectile motion, how would you describe a projectile? Think of an object thrown into the air, and consider the primary force that pulls it back down.', 'tag': 'teacher_1_question_1_0006', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0006.wav?download=true', 'responses': [{'speaker': 'student_2', 'message': 'Okay so a projectile is just anything you throw or launch into the air. And the main thing pulling it back down is gravity.', 'tag': 'student_2_question_1_0004', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/student_2_question_1_0004.wav?download=true', 'responses': [{'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0007', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0007.wav?download=true', 'responses': []}]}, {'speaker': 'student_3', 'message': "A projectile is any object that's thrown or launched into the air. Once it's movi ...

# %%
node = find_node_by_tag('teacher_1_question_1_0015')
print(node)
# Out:
# {'speaker': 'teacher_1', 'message': "That's correct!", 'tag': 'teacher_1_question_1_0015', 'audio link': 'https://huggingface.co/datasets/itsybitsci/audio/resolve/main/teacher_1_question_1_0015.wav?download=true', 'responses': []}
